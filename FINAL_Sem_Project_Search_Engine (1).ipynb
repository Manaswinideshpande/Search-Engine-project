# %% [markdown]
# ###           Project Statement - Enhancing Search Engine Relevance for Video Subtitles

# %% [markdown]
# ### AIM Of The Project
# In the fast-evolving landscape of digital content, effective search engines play a pivotal role in connecting users with relevant information. For Google, providing a seamless and accurate search experience is paramount. This project focuses on improving the search relevance for video subtitles, enhancing the accessibility of video content.

# %% [markdown]
# ### Objective:
# Developing an advanced search engine algorithm that efficiently retrieves subtitles based on user queries, with a specific emphasis on subtitle content.
# The primary goal is
# to leverage natural language processing and machine learning techniques to enhance the relevance and accuracy of search results.

# %% [markdown]
# ## **Step 1 - Reading the Tables from Database file**

# %%
import sqlite3
import pandas as pd

# %%
# Read the code below and write your observation in the next cell

conn = sqlite3.connect(r'C:/Users/deshp/Downloads/data/eng_subtitles_database.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cursor.fetchall())
#"C:\Users\deshp\Downloads\data\eng_subtitles_database.db"
# Out:
# [('zipfiles',)]

# %% [markdown]
# **In the above cell, I am able to read the table inside the database. As mentioned earlier, table name is `zipfiles`. We also know from README.txt that this table contains three columns: 'num', 'name' and 'content'.**

# %% [markdown]
# ## **Step 2 - Reading the columns of Table**

# %%
cursor.execute("PRAGMA table_info('zipfiles')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])
# Out:
# num
# name
# content

# %% [markdown]
# **The above code helps in checking the column names in the database table.**
#
# **Let's now use `SELECT * FROM zipfiles` to read all the data into a `df` variable.**

# %% [markdown]
# ## **Step 3 - Loading the Database Table inside a Pandas DataFrame**

# %%
df = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...

# %%
len(df)
# Out:
# 82498

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82498 entries, 0 to 82497
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   num      82498 non-null  int64
#  1   name     82498 non-null  object
#  2   content  82498 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# **Looks like the `content` column donot contain the subtitles text. Instead as mentioned in README.txt, it might be latin-1 encoded.**

# %% [markdown]
# ## **Step 4 - Printing `content` of 0th Row**

# %%
b_data = df.iloc[0, 2]

# here 2 represent the index of content column
# 0 represents the row number

# %%
print(b_data)
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x99V\x9fx\x96\xf0\x8c\x9e\x00\x00\x86\x9b\x01\x00;\x00\x00\x00The.Message.1976.REMASTERED.1080p.BluRay.x264-PiGNUS.EN.srt\xad\xbdm\x93\xdc\xc6\x91.\xfa\x9d\x11\xfc\x0f-}\xe1=\x11-\x9d\x06P\x85\x17\x9d\x8d\xd5%%[\xa4-Y>&u\x15>\xdf\xd0\xd3\x98\x19x\xfae\x0cts<\xfe\xf57\x9f\'\xb3\n\xd9\xa4\xbc\xbb\xf7\xc6Fl\xacELW\xa2\xaa\x90\x95\x95\xafO\x16/_l6\xdf\xe0\xff\xea\xf5f\xb3Y}\xf5\xd5\xbf\xaf\xf4AQ\xae7Mx\xf9\xe2\xd7\xfe|s\xbf\xea\x8f\xcf\xab\x8f\xe3n8\xadN\xc7\xfdx\x1cVO\xe3\xf9~\xf5\xf3\xe3p\xfc\xea\xfd/o>\xbc\xfb\xf0\xe3\xef\xde\xbf|\xf1\xfbi\x18Vo\xa6\xd3\xd3<L\xab\xe1\x1f\xe7\xe18\x8f\xa7\xe37\xab\xd3\xbc\xdb~-\xc3\x1e\xfe\xa7<|\xf9\xe2\xe5\x8bR_[~S\xd6\xeb\xa2k\xf3k\xe5A\xb7\xeeb\xf5\xf2\xc5\xbb\xe3\xea|?\xac\x8e\xfdaX\x9dnW?\x9cvk>8\x9c\xe6\xf3\xean\xeao\xc6\xd3ev\x8f~\x1a\xa6\x9b\xf1\xf6\xb2\xff\x1a\xe4\xabD\xbe*d\x11\xa5#_U\xeb\xaa\xd9`\xa6\xa7\xc3\xea\xa7\xcb}\x7f8\xf4F\xf9\xa7a\x9e\x87\xe3\x9d\xcc\\\xdf\x07B!\x13\xaa\xd61n<!\xd9\xaf\xd0\xbc|q>\xad\xde\x0e2\x9d\xfd\x98\xa63\x1c\x1e\x87\xe9D*o\x9e\xff\xd9\x1f\xcf\xe3\xe5\xc0Y\xc5L\xac^\x87M\xe3\x89u\xebP\xcb\xbb\xeed\xff\xce\xe3\xf1n^\t\xd9\xfb\xf1\xb0z\xba?\xad\xc6\x19d_\xbe\xb8=\xed\xf7\xa7\'\x9d\xde4\xde\xdd\x9f\x07\xd9\x81\xd5\xdde\xdc\xf5\xc7\x9b\x81o\xa8\xf3\x1b\xbau\xd3V\xee\r\xa1\\\xc7\xae\x90m]m\xc7\xdd\xea\xf9t\xe1\x1b\x86~\xe2\x94w\xe3G|\xd3\x9b~\xaf\xfb\xd7$:\xa1Z\x17\xb5_v\x88\xeb\xb6h@\xa7?\xe8\xe6\x7f\xb2k\xa0\x8b\xe7\x8f\xc3\xe9q?\xfc/Pk3\xb5z]U~\xdd\xa1\x95i\xca\xba\xfb\x9b\x9b\xe1\xf1\xbcz7\xef\x85\xea\xad\xec\x9dLpZ\xcd\xfd\xfec\x7f\x16\x06\xe2\x9c\xbaD%\x96\xeb\xb2*\x1c\x95\x18\xd6\xcdF\xfe\xfcvX\xcd\x8fC\xff0c*\xfd\xea8<\xad\x1e\xa7\xd3\xe3\xfdp^\x8d\xc7\xd5\xeb\xa9\xdf\x8e=I\x15\x9bL+\xae7\xb5g\xbf\xd8\xac\xdb2\x82\xeb\xe7\xd5x^\xed\xc7\x87A\x96#\x9f\xe0\xe9~8\xae\xfep\xba?\xeaG~\xd3?\x9e\xc7Yx\xf9\x06\x0c*k~\x90\xcf\x06NP\xbe)\x8a\xfc\x86v]\x84\x98\xdfP}\xb3)\xd6e#\xfc\x7f\xba\x9c1On\xff \xe7\xe5\xbc^\xddL\xcf\xa0\xd2o\xf1\xb7\xbc\xfaoI\xd0NL\xc5\x13S\xd5\x8e`\xd9\xae\xbb\x8dp\xfc\x87\x930\xf4\xdf\xfb\xa7\xbf\x8f\xc2\x88\x7f\xee\xcf\xd3\xd8Orr\xe5\x1d\xaf\xf7\xc3?\xfa\xe3nJ\xcb\xaf\x12-\xe1\x8a\xe0\x0e\xbd<\x08\xeb\xba\x92\xef\xf5\xc7q\x9e\xfa\xb5g\xe5?\x0f\xd3\x9c\xc6\x87<^v>6~|\xb3\x0e\x9dl_:Yd\xa9\x99\xfcF\x81\x81\xd5\xe2\x911\x8b\x92\x8b\x99\\\xb3n\x8a\xe0\xc8\xc5\x8d\x9c:\xd9\xca\xd7\xff\t\x7f|\xad\x84\xeaDH\xc6\xb5\x9d_\x97\xf0L\x08\xc2"\xc3a+guPJ:\xa8\xc9\x83\xc2\xba\xac\xfdb\xe4\xd35\xa5\xec\xfb_e\xf67\'\xc8\xa1\xcf>\xd9\xcb\x17\xf3a\xd8\xef\xf1\xd5\xe4\x0f\xe0\x85\xbd\x88\xca\xdd\xea\xee\xd4\x9f\x95|\x9b\xc9\x83\xd7\x17Q\x14D\xc6\xcaQ\xda\xf0\xbb\x9d\x85\x86\xed0\x18m\x1a\xe4h\xae\xe6\xfb\xd3e\xbf[=\x1c\x87a\xaf<`G@\x86vr\x90<\xad\xa2X\xd7\x9b\xcd\xb2\xef\xeb\xcf\xa4\x19gSn\x12\x85\xa2Z\xd7\xa1\xf5\x14\xe2\xba\xda\xc8\x06\xfe*\x12\xe7\xae\xff8P\xfc\x90\xf3\xfb\xcb\xf9\xfe4\x8d\xe7gN\xa2,2\x89(\x0b\x8a\x9e\x84\xac0\xc8~A\n\xc8\xbb\xcfY\xbe\xca\x01\x172"*\xa6\x9bg\x9c\x95C\x7f\x94\xe3bS2\xc6\x8e\x98R\xe5\x98)~SF9)\xc2k\x1fd3\xde\xdf\xdc\x9f\xf6\xfd4sw\xdf\xca\xc9\x93\x19\xf5G\x9et\xe5\x8a\xaf\xf4w\xbf\x1c\xc7\x8f\xd8\xc7\xf3\xb32\xfeW\xaf\xffy/BN\xce\xffw\xfd8\x9d\xf4GoEz\xea\xb0\xf1f\xf5\xdd\xe9(bw\x9e\xd3\x97}\x7f?\xf6\x14\x18?\x0e\xdb\xfex:r\x92U\x9a$N\xdf\xa6r\x93\x94\x8b\xa1\tQ\xe9\x1e\xfa\x07y\xb7\x12\x92\x8d\xbb\x1d\xf7\x87\xd5\xfd\xe9\x08^\x05\xe5\xf4\xc6\xf3\xd4\xefF\xf0\xed\xcb\x17O\xf7\xa3\x1cQY\xda\x0eB^\xde\xcb\xdf\xe1\xd4\xcd\xa7#y;M\xeb\xcf*\xc9Dn\xdc\xde\x0eG\xf9y\x7f\xd7\x8f\xc7YG\xcc\x8f\xa3|\xa0K\xbf\xb7u\xe3\xed\x10\xcc\xfd\x9d\xde\x0beH\xf3\xc7t\xddG\x8b\x10\xe8U\xab\x9b<\rr\xb4\x86\xb5\x89o\xcc\x00\xb4~:\xa5\x8f\xf84\n\x97\x1eO\xe7\xd5\x96\xcc\xf9\xa4r\xb9\x8c\x89\xb6\x9c\xba\xcd\xa6s\xb4c%w\xa4\xf0\xd4\xbf\x8d\xff.\xdc\xb9z\x1e\xf8\x01o\xcf\xc2\x94\xdf\xddO\xf2\x11\xe5\xe2\x19v\xeb\x7f\xfb\x9f\xe3\xbf\x93R\x9d)U\xeb2\xd4\x9eRT\xd6\x12J\x14\xc4\xbf\xbb\xc8v\x88\x12"|5_\x8e\x0f\xf8\\<\x95\xfd\xf4 \x1b3\xcc\x99d\x93I\xca\xc5\xb5)=\xc9v]7\x1dI\x82\xa7\x06a\x9bg={\xa0$_Dd\xbb\\\x8b\x ...

# %% [markdown]
# **From the content, it appears to start with the bytes "PK\x03\......", which suggests that it might be a ZIP archive file. How do I know it? Experience! I have worked with something similar earlier.**

# %% [markdown]
# ## **Step 5 - Unzipping the content of 380th row and decoding using `latin-1`**

# %%
import zipfile
import io

# Assuming 'content' is the binary data from your database
binary_data = df.iloc[380, 2]

# Decompress the binary data using the zipfile module
with io.BytesIO(binary_data) as f:
    with zipfile.ZipFile(f, 'r') as zip_file:
        # Reading only one file in the ZIP archive
        subtitle_content = zip_file.read(zip_file.namelist()[0])

# Now 'subtitle_content' should contain the extracted subtitle content
print(subtitle_content.decode('latin-1'))  # Assuming the content is latin-1 encoded text
# Out:
# ï»¿1
# 00:00:10,543 --> 00:00:13,083
# Previously on
# "The Great Food Truck Race"...
#
# 2
# 00:00:13,079 --> 00:00:15,779
# Eight teams of aspiring
# food truck owners
#
# 3
# 00:00:15,782 --> 00:00:17,982
# launched a frantic
# crossâcountry journey.
#
# 4
# 00:00:17,984 --> 00:00:19,694
# The prize?
#
# 5
# 00:00:19,686 --> 00:00:22,186
# A stateâofâtheâart
# food truck and $50,000.
#
# 6
# 00:00:22,188 --> 00:00:24,388
# Yeah, buddy!
# For five
# of those teams,
#
# 7
# 00:00:24,391 --> 00:00:25,891
# what started as
# a dream come true
#
# 8
# 00:00:25,892 --> 00:00:27,662
# became a wake up call.
#
# 9
# 00:00:27,660 --> 00:00:28,900
# I got beat by
# a quesadilla.
#
# 10
# 00:00:28,895 --> 00:00:31,125
# Now,
# only three teams remain.
#
# 11
# 00:00:31,197 --> 00:00:33,567
# Lone Star Chuck Wagon
# started the race
#
# 12
# 00:00:33,566 --> 00:00:35,436
# by taking first place
# in Venice Beach.
#
# 13
# 00:00:35,435 --> 00:00:38,905
# But in Oklahoma City,
# they almost went home.
#
# 14
# 00:00:38,905 --> 00:00:40,665
# It's too much work
# to get sent home.
#
# 15
# 00:00:40,673 --> 00:00:42,013
# However,
# in St. Louis,
#
# 16
# 00:00:42,008 --> 00:00:44,678
# a rock star performance
# put them back on top,
#
# 17
# 00:00:44,677 --> 00:00:47,777
# Congratulations.
# making Lone Star
# the team to beat.
#
# 18
# 00:00:47,781 --> 00:00:49,721
# Obviously there's a giant bulls
# eye on our back.
#
# 19
# 00:00:49,716 --> 00:00:51,716
# Let There Be Bacon
# had a rough start
#
# 20
# 00:00:51,718 --> 00:00:53,548
# and barely made it out
# of the first city.
#
# 21
# 00:00:53,553 --> 00:00:55,893
# Frustrating as hell.
# Since then,
# they've recruited
#
# 22
# 00:00:55,889 --> 00:00:57,989
# a Bacon Army
# in every town.
#
# 23
# 00:00:57,991 --> 00:00:59,361
# Bacon! Bacon!
#
# 24
# 00:00:59,359 --> 00:01:01,799
# Bacon will
# always live on!
#
# 25
# 00:01:01,795 --> 00:01:03,095
# And then
# there's Middle Feast.
#
# 26
# 00:01:03,096 --> 00:01:05,296
# Last week in St. Louis,
#
# 27
# 00:01:05,298 --> 00:01:07,498
# they found themselves
# back in the bottom two,
#
# 28
# 00:01:07,500 --> 00:01:10,740
# Middle Feat.
# but managed to
# outâearn Beach Cruiser
#
# 29
# 00:01:10,737 --> 00:01:14,067
# by $160, sending
# the former favorites
#
# 30
# 00:01:14,074 --> 00:01:16,144
# home to Venice,
# California.
#
# 31
# 00:01:16,142 --> 00:01:19,312
# And now the race comes here,
# to Mobile, Alabama.
#
# 32
# 00:01:19,312 --> 00:01:22,152
# Only three trucks remain,
# but not for long.
#
# 33
# 00:01:22,148 --> 00:01:23,518
# Who will go home next?
#
# 34
# 00:01:23,516 --> 00:01:25,616
# There's only one way
# to find out.
#
# 35
# 00:01:25,618 --> 00:01:27,048
# I'm Tyler Florence,
#
# 36
# 00:01:27,053 --> 00:01:29,993
# and this is
# "The Great Food Truck Race."
#
# 37
# 00:01:29,989 --> 00:01:31,359
# Let's get rolling.
#
# 38
# 00:01:31,357 --> 00:01:34,357
# Food Truck Road Trip!
#
# 39
# 00:01:36,000 --> 00:01:42,074
# api.OpenSubtitles.org is deprecated, please
# implement REST API from OpenSubtitles.com
#
# 40
# 00:01:47,474 --> 00:01:49,614
# We're in second place.
#
# 41
# 00:01:49,609 --> 00:01:51,179
# Second place, man,
# from seventh.
#
# 42
# 00:01:51,177 --> 00:01:52,777
# From seventh.
# From seventh place.
#
# 43
# 00:01:52,779 --> 00:01:55,079
# Going on in this competition
# means everything to us.
#
# 44
# 00:01:55,081 --> 00:01:57,121
# It affects our whole family
# and all of our friends
#
# 45
# 00:01:57,116 --> 00:01:59,716
# and everything that
# we do moving forward.
#
# 46
# 00:01:59,719 --> 00:02:02,019
# If we go back,
# we're going back to nothing.
#
# 47
# 00:02:02,021 --> 00:02:03,921
# Like, we're going back
# to no jobs,
#
# 48
# 00:02:03,923 --> 00:02:06,563
# we're going back to the same
# problems that we left.
#
# 49
# 00:02:06,559 --> 00:02:08,429
# I want something better
# for Matt and Dylan.
#
# 50
# 00:02:08,428 --> 00:02:10,298
# I want something
# better for myself.
#
# 51
# 00:02:10,296 --> 00:02:12,926
# I think we need to take
# what Tyler said to heart.
#
# 52
# 00:02:12,932 --> 00:02:14,232
# I think we need to
# start focusing
#
# 53
# 00:02:14,234 --> 00:02:15,544
# on bacon more
# as our main protein.
#
# 54
# 00:02:15,535 --> 00:02:17,135
# I agree with you.
#
# 55
# 00:02:17,203 --> 00:02:19,413
# Sweet home Alabama.
#
# 56
# 00:02:19,405 --> 00:02:22,605
# I think they really like
# seafood and fish over here.
#
# 57
# 00:02:22,609 --> 00:02:27,079
# I think the spicy Moroccan
# fish tacos will play good.
#
# 58
# 00:02:27,080 --> 00:02:29,550
# We were thinking the whole race
# that it's our disadvantage
#
# 59
# 00:02:29,549 --> 00:02:31,219
# that we're not doing
# something, like,
#
# 60
# 00:02:31,217 --> 00:02:34,387
# American, but now I understand
# it's our advantage.
#
# 61
# 00:02:34,387 --> 00:02:35,917
# People want to try
# different stuff,
#
# 62
# 00:02:35,922 --> 00:02:37,192
# and we are definitely different.
#
# 63
# 00:02:37,190 --> 00:02:39,190
# You can get TexâMex anywhere
#
# 64
# 00:02:39,192 --> 00:02:41,592
# <i>and bacon everywhere,</i>
#
# 65
# 00:02:41,594 --> 00:02:45,434
# but Israeli/American
# fusion cuisine,
#
# 66
# 00:02:45,431 --> 00:02:46,771
# that's special.
#
# 67
# 00:02:46,766 --> 00:02:48,536
# There's only
# three teams left,
#
# 68
# 00:02:48,535 --> 00:02:50,565
# so if we win this,
# then we're in the finale.
#
# 69
# 00:02:50,570 --> 00:02:52,440
# I know there's a lot of
# displaced Texans
#
# 70
# 00:02:52,438 --> 00:02:53,568
# out here as well.
#
# 71
# 00:02:53,573 --> 00:02:55,983
# Last week's menu put us
# in first place.
#
# 72
# 00:02:55,975 --> 00:02:58,305
# Our confidence is at
# an allâtime high
#
# 73
# 00:02:58,311 --> 00:03:00,081
# for this competition.
#
# 74
# 00:03:00,079 --> 00:03:01,849
# We can't wait to get to Mobile
# and show 'em what we got.
#
# 75
# 00:03:01,848 --> 00:03:04,078
# Oh, Mammy.
# It's your little boy Sammy.
#
# 76
# 00:03:04,083 --> 00:03:05,623
# And we're all from Alabamy.
#
# 77
# 00:03:05,618 --> 00:03:07,788
# Don't give me
# no flimâflammy, Mammy.
#
# 78
# 00:03:07,787 --> 00:03:10,217
# Look at all those
# eggs and hammy.
#
# 79
# 00:03:16,229 --> 00:03:18,199
# Hey, what's up, guys?
# How are you?
#
# 80
# 00:03:18,197 --> 00:03:19,567
# Good to see you, man.
# What's up?
#
# 81
# 00:03:19,566 --> 00:03:21,466
# I wanted to own my own
# restaurant for a long time,
#
# 82
# 00:03:21,467 --> 00:03:23,537
# and after going through cancer,
# it didn't look like
#
# 83
# 00:03:23,536 --> 00:03:25,096
# it was going to happen.
#
# 84
# 00:03:25,104 --> 00:03:26,914
# There's only three teams
# left in this competition.
#
# 85
# 00:03:26,906 --> 00:03:28,936
# We're so close to owning this
# food truck, we can taste it.
#
# 86
# 00:03:28,942 --> 00:03:32,282
# Hey, guys, welcome
# to Bayou La Batre, Alabama,
#
# 87
# 00:03:32,278 --> 00:03:35,618
# the heart of
# shrimping country.
#
# 88
# 00:03:35,615 --> 00:03:37,075
# Cool, huh?
#
# 89
# 00:03:37,083 --> 00:03:40,453
# So, guys, we've been on the road
# for over 2,600 miles,
#
# 90
# 00:03:40,453 --> 00:03:43,593
# and we are now on the coast
# for the first time
#
# 91
# 00:03:43,590 --> 00:03:45,290
# since Venice, California.
#
# 92
# 00:03:45,291 --> 00:03:47,931
# We're 30 miles outside of
# Mobile, Alabama,
#
# 93
# 00:03:47,927 --> 00:03:51,697
# a beautiful little port city
# with over 200,000 people,
#
# 94
# 00:03:51,698 --> 00:03:54,298
# and out there is
# the Gulf of Mexico,
#
# 95
# 00:03:54,300 --> 00:03:57,370
# just teeming with tons
# of fresh American seafood
#
# 96
# 00:03:57,370 --> 00:03:58,940
# waiting to be harvested.
#
# 97
# 00:03:58,938 --> 00:04:01,638
# Gulf seafood has inspired
# some of the tastiest cooking
#
# 98
# 00:04:01,641 --> 00:04:02,711
# in the United States
#
# 99
# 00:04:02,709 --> 00:04:05,379
# and it's going to
# inspire us in Mobile,
#
# 100
# 00:04:05,378 --> 00:04:08,208
# because this week is about
# cooking locally.
#
# 101
# 00:04:08,214 --> 00:04:10,284
# Even though you have
# your own brand
#
# 102
# 00:04:10,283 --> 00:04:12,423
# and your signature dishes,
# you can still be
#
# 103
# 00:04:12,418 --> 00:04:14,748
# inspired by
# local ingredients.
#
# 104
# 00:04:14,754 --> 00:04:16,194
# That's why this weekend,
#
# 105
# 00:04:16,189 --> 00:04:18,519
# I want you to add
# three seafood dishes
#
# 106
# 00:04:18,524 --> 00:04:19,994
# to your menu.
#
# 107
# 00:04:19,993 --> 00:04:23,263
# Being told we have to cook three
# seafood options kind of opens up
#
# 108
# 00:04:23,263 --> 00:04:25,573
# a whole new world of
# possibilities for us,
#
# 109
# 00:04:25,565 --> 00:04:27,095
# so I'm kind of excited.
#
# 110
# 00:04:27,100 --> 00:04:29,000
# So, guys, let's talk
# about seed money.
#
# 111
# 00:04:29,002 --> 00:04:32,112
# So in St. Louis,
# I didn't give you a penny.
#
# 112
# 00:04:32,105 --> 00:04:34,265
# I'm not going to be mean
# like that two weeks in a row.
#
# 113
# 00:04:34,273 --> 00:04:37,113
# This week, I am all about
# Southern hospitality.
#
# 114
# 00:04:37,110 --> 00:04:39,110
# I've got $400 for each
# and every one of you.
#
# 115
# 00:04:39,112 --> 00:04:41,352
# Nice.
# Nice, right?
#
# 116
# 00:04:41,347 --> 00:04:44,247
# $400 is exactly what we need.
# It's so exciting.
#
# 117
# 00:04:44,250 --> 00:04:45,720
# It gives us a lot
# of breathing room.
#
# 118
# 00:04:45,718 --> 00:04:47,918
# We're going to be able to get
# the perfect amount of product.
#
# 119
# 00:04:47,920 --> 00:04:49,490
# So, since I'm being nice,
#
# 120
# 00:04:49,489 --> 00:04:52,489
# I'm going to give you guys
# more than seed money.
#
# 121
# 00:04:52,492 --> 00:04:54,592
# Well, not really <i>give</i> you,
#
# 122
# 00:04:54,594 --> 00:04:57,064
# but I'm going to give you
# the chance to earn
#
# 123
# 00:04:57,063 --> 00:04:59,733
# some incredibly fresh
# Gulf shrimp
#
# 124
# 00:04:59,732 --> 00:05:01,872
# that just came off that boat.
#
# 125
# 00:05:01,868 --> 00:05:04,398
# Guys, I want to introduce you
# to Dominick Ficarino.
#
# 126
# 00:05:04,404 --> 00:05:07,844
# He owns eight of
# these shrimp boats,
#
# 127
# 00:05:07,840 --> 00:05:09,980
# and Dominick has graciously
#
# 128
# 00:05:09,976 --> 00:05:13,306
# donated some of his
# beautiful shrimp
#
# 129
# 00:05:13,313 --> 00:05:15,313
# to your food trucks
# this weekend,
#
# 130
# 00:05:15,314 --> 00:05:16,954
# but you're going
# to have to earn it.
#
# 131
# 00:05:16,949 --> 00:05:20,019
# I'm going to send you
# into this freezer.
#
# 132
# 00:05:20,019 --> 00:05:23,219
# There's going to be three large
# totes full of shrimp.
#
# 133
# 00:05:23,222 --> 00:05:26,592
# Each team come out with what you
# believe is 100 pounds.
#
# 134
# 00:05:26,592 --> 00:05:29,802
# So the team that
# comes the closest to
#
# 135
# 00:05:29,796 --> 00:05:31,956
# 100 pounds exactly gets to
# keep whatever shrimp
#
# 136
# 00:05:31,964 --> 00:05:33,804
# you bring out of
# the freezer for free.
#
# 137
# 00:05:33,800 --> 00:05:36,000
# And then for the teams
#
# 138
# 00:05:36,002 --> 00:05:37,672
# who don't come close,
# who come in second
#
# 139
# 00:05:37,670 --> 00:05:39,040
# and third,
# what do they get to do?
#
# 140
# 00:05:39,038 --> 00:05:40,408
# You're going to get
# to purchase some,
#
# 141
# 00:05:40,406 --> 00:05:41,706
# get that opportunity.
#
# 142
# 00:05:41,708 --> 00:05:43,208
# We really need to win
# the shrimp challenge.
#
# 143
# 00:05:43,209 --> 00:05:45,209
# We only have $400,
# bacon's expensive,
#
# 144
# 00:05:45,211 --> 00:05:48,681
# and 100 pounds of free product
# would be amazing.
#
# 145
# 00:05:48,681 --> 00:05:50,781
# Teams, do you
# understand the rules?
# Yes.
#
# 146
# 00:05:50,783 --> 00:05:52,293
# We will meet you
# back at the scale.
#
# 147
# 00:05:52,285 --> 00:05:53,885
# You ready to
# send them off?
#
# 148
# 00:05:53,886 --> 00:05:54,886
# Ready, set, go!
#
# 149
# 00:05:54,887 --> 00:05:56,457
# Let's go, guys!
#
# 150
# 00:06:02,228 --> 00:06:03,958
# Woo!
#
# 151
# 00:06:03,963 --> 00:06:05,003
# All right.
#
# 152
# 00:06:04,997 --> 00:06:06,267
# Oh.
#
# 153
# 00:06:06,265 --> 00:06:07,325
# Woohoo!
#
# 154
# 00:06:07,333 --> 00:06:08,573
# Oh, my god.
#
# 155
# 00:06:08,568 --> 00:06:10,898
# Put it in your hat.
# Use your hat.
#
# 156
# 00:06:10,903 --> 00:06:13,173
# Can't even get them
# in my hands right now.
#
# 157
# 00:06:13,172 --> 00:06:15,242
# All right, tough it out, girls.
# We got this.
#
# 158
# 00:06:15,241 --> 00:06:17,641
# Holy smokes, it's really
# cold in here.
#
# 159
# 00:06:19,479 --> 00:06:20,749
# The only way to
#
# 160
# 00:06:20,747 --> 00:06:23,817
# get through this pain
# is to scream it out.
#
# 161
# 00:06:26,285 --> 00:06:28,115
# I'm chilled
# to the bones!
#
# 162
# 00:06:30,356 --> 00:06:32,586
# You can hear
# other teams screaming
#
# 163
# 00:06:32,592 --> 00:06:34,662
# because it's so cold,
#
# 164
# 00:06:34,660 --> 00:06:35,800
# and it's kind of funny.
#
# 165
# 00:06:37,830 --> 00:06:40,200
# I would guess probably
# 12 a pound?
#
# 166
# 00:06:40,199 --> 00:06:42,539
# Normally when you guy shrimp
# it comes in by count,
#
# 167
# 00:06:42,535 --> 00:06:45,535
# so our strategy is to go in,
# assess the size of the shrimp,
#
# 168
# 00:06:45,538 --> 00:06:47,438
# and determine how much
# we need per pound
#
# 169
# 00:06:47,440 --> 00:06:48,470
# and then count it all out.
#
# 170
# 00:06:50,243 --> 00:06:52,043
# Let me see your bags.
# I've got close to
#
# 171
# 00:06:52,044 --> 00:06:53,384
# 18 pounds right here.
#
# 172
# 00:06:53,379 --> 00:06:55,479
# What do you think?
# More.
#
# 173
# 00:06:55,481 --> 00:06:57,851
# We have no idea
# if we're even close,
#
# 174
# 00:06:57,850 --> 00:06:59,550
# and then I was thinking,
#
# 175
# 00:06:59,552 --> 00:07:02,592
# "Wait a minute.
# I weigh about 100 pounds."
#
# 176
# 00:07:02,588 --> 00:07:04,888
# 100 pounds?
#
# 177
# 00:07:04,891 --> 00:07:06,531
# Oh, that's pretty close, boys.
#
# 178
# 00:07:06,526 --> 00:07:08,386
# Good.
# I think we're good.
#
# 179
# 00:07:08,394 --> 00:07:09,734
# I think we're good.
# Yeah?
#
# 180
# 00:07:12,465 --> 00:07:13,695
# Good counting,
# gentlemen.
#
# 181
# 00:07:13,699 --> 00:07:14,999
# I'm pretty confident
# that we have
#
# 182
# 00:07:15,001 --> 00:07:17,101
# at least 70 pounds
# of shrimp in this bag.
#
# 183
# 00:07:17,103 --> 00:07:18,303
# I think there's a good chance
#
# 184
# 00:07:18,304 --> 00:07:19,944
# we could win
# this weighing challenge.
#
# 185
# 00:07:19,939 --> 00:07:21,369
# All right, so,
#
# 186
# 00:07:21,374 --> 00:07:23,684
# you're supposed to get as close
# to 100 pounds as possible.
#
# 187
# 00:07:23,676 --> 00:07:25,676
# Teams get as close as possible
# wins their shrimp.
#
# 188
# 00:07:25,678 --> 00:07:27,708
# All right,
# Lone Star Chuck Wagon,
#
# 189
# 00:07:27,713 --> 00:07:29,453
# you guys won the last city,
# you go first.
#
# 190
# 00:07:40,993 --> 00:07:44,763
# So Lone Star Chuck Wagon
# has 77 pounds of shrimp.
#
# 191
# 00:07:44,764 --> 00:07:46,334
# Middle Feast,
# come on up.
#
# 192
# 00:07:46,332 --> 00:07:48,232
# One at a time, guys,
# one at a time.
#
# 193
# 00:07:50,436 --> 00:07:51,496
# Pounds.
#
# 194
# 00:07:51,504 --> 00:07:53,944
# 49 pounds.
#
# 195
# 00:07:53,940 --> 00:07:56,510
# Middle Feast,
# I'm sorry,
#
# 196
# 00:07:56,509 --> 00:07:58,179
# you guys are out.
# Bacon, you're up next.
#
# 197
# 00:08:02,882 --> 00:08:04,952
# What do we have?
#
# 198
# 00:08:11,157 --> 00:08:12,987
# You're supposed
# to get as close
#
# 199
# 00:08:12,992 --> 00:08:14,332
# to 100 pounds
# as possible.
#
# 200
# 00:08:14,327 --> 00:08:17,157
# Middle Feast, I'm sorry,
# you guys are out.
#
# 201
# 00:08:17,163 --> 00:08:17,903
# Lone Star,
# you're in really good shape
#
# 202
# 00:08:17,897 --> 00:08:18,967
# with 77 pounds.
#
# 203
# 00:08:18,965 --> 00:08:20,695
# Bacon, you're up next.
#
# 204
# 00:08:25,872 --> 00:08:27,612
# What do we got?
#
# 205
# 00:08:30,476 --> 00:08:33,176
# Let There Be Bacon's got 55,
# Lone Star Chuck Wagon
#
# 206
# 00:08:33,179 --> 00:08:34,979
# is closest to
# 100 pounds of shrimp.
#
# 207
# 00:08:34,981 --> 00:08:36,381
# Oh, yeah, that's right.
#
# 208
# 00:08:36,382 --> 00:08:38,852
# You don't weigh things
# by counting them.
#
# 209
# 00:08:41,187 --> 00:08:44,687
# Lone Star Chuck Wagon,
# you've got 77 pounds of free,
#
# 210
# 00:08:44,690 --> 00:08:46,990
# beautiful Gulf Coast shrimp.
#
# 211
# 00:08:46,993 --> 00:08:48,393
# Woohoo!
# Yeah!
#
# 212
# 00:08:48,394 --> 00:08:49,764
# These shrimp are big,
#
# 213
# 00:08:49,762 --> 00:08:52,062
# they're beautiful,
# they're fresh,
#
# 214
# 00:08:52,064 --> 00:08:54,034
# and we get to sell it
# out of our food truck
#
# 215
# 00:08:54,033 --> 00:08:55,703
# and we get it for free.
#
# 216
# 00:08:55,701 --> 00:08:56,901
# It's incredible.
#
# 217
# 00:08:58,704 --> 00:09:00,374
# Anybody want to
# buy some shrimp?
#
# 218
# 00:09:00,373 --> 00:09:01,913
# How much does it go for?
#
# 219
# 00:09:01,908 --> 00:09:03,408
# Say about $9 a pound.
#
# 220
# 00:09:03,409 --> 00:09:04,609
# That shrimp right there
#
# 221
# 00:09:04,610 --> 00:09:06,250
# in the supermarket
# is going to go, shoot,
#
# 222
# 00:09:06,245 --> 00:09:07,705
# about $16.99 a pound.
#
# 223
# 00:09:07,713 --> 00:09:09,053
# All right, we'll pass.
#
# 224
# 00:09:09,048 --> 00:09:10,118
# Y'all going to pass?
#
# 225
# 00:09:10,116 --> 00:09:11,776
# I don't want
# that shrimp.
#
# 226
# 00:09:11,784 --> 00:09:14,394
# I know how difficult
# it is to peel it
#
# 227
# 00:09:14,387 --> 00:09:15,657
# and to prepare it.
#
# 228
# 00:09:15,655 --> 00:09:17,655
# We already got a really good
# lesson on prep time,
#
# 229
# 00:09:17,657 --> 00:09:19,157
# so I'm not playing with that.
#
# 230
# 00:09:19,158 --> 00:09:21,528
# What do you guys think,
# 15 pounds?
#
# 231
# 00:09:21,527 --> 00:09:22,597
# 15 pounds?
# Yeah.
#
# 232
# 00:09:22,595 --> 00:09:24,525
# Tyler said
# the theme this week
#
# 233
# 00:09:24,530 --> 00:09:25,670
# is cooking locally,
#
# 234
# 00:09:25,665 --> 00:09:27,595
# so you buy
# 15 pounds of shrimp,
#
# 235
# 00:09:27,600 --> 00:09:31,740
# you don't get any more local
# than right here, right now.
#
# 236
# 00:09:31,737 --> 00:09:33,807
# Good luck to you, hear?
# Thank you.
#
# 237
# 00:09:39,278 --> 00:09:41,108
# You want to do
# the blackened salmon?
# Yeah.
#
# 238
# 00:09:41,113 --> 00:09:44,023
# It tastes better and we can
# sell it for more money.
#
# 239
# 00:09:44,016 --> 00:09:46,846
# Because of the seafood
# challenge this week,
#
# 240
# 00:09:46,852 --> 00:09:49,222
# we've decided to go
# blackened salmon
#
# 241
# 00:09:49,221 --> 00:09:52,491
# and spicy Moroccan
# fish tacos,
#
# 242
# 00:09:52,491 --> 00:09:55,231
# fried tilapia schnitzels
# with garlic lemon aioli.
#
# 243
# 00:09:55,227 --> 00:09:56,727
# Um...
#
# 244
# 00:09:56,729 --> 00:09:57,959
# We're doing seafood,
#
# 245
# 00:09:57,964 --> 00:09:59,934
# so those shrimp
# need a lot of butter on 'em.
#
# 246
# 00:09:59,932 --> 00:10:01,132
# With all this
# beautiful shrimp,
#
# 247
# 00:10:01,133 --> 00:10:02,673
# we're going to
# take off chicken,
#
# 248
# 00:10:02,668 --> 00:10:03,968
# but we're leaving steak.
#
# 249
# 00:10:03,970 --> 00:10:06,640
# We're the Lone Star Chuck Wagon.
# We have to have steak.
#
# 250
# 00:10:06,639 --> 00:10:08,539
# We have $400,
# you guys.
#
# 251
# 00:10:08,541 --> 00:10:10,811
# How many of these
# you guys want to get?
# 4 at 2.28.
#
# 252
# 00:10:10,810 --> 00:10:12,180
# We're using our
# local ingredients,
#
# 253
# 00:10:12,178 --> 00:10:14,248
# so we're going to do
# a bacon fried shrimp po' boy,
#
# 254
# 00:10:14,246 --> 00:10:17,176
# a Koreanâstyle blackened shrimp
# and bacon ssam,
#
# 255
# 00:10:17,183 --> 00:10:19,523
# which is a lettuce wrap,
# and we're going to do
#
# 256
# 00:10:19,518 --> 00:10:20,788
# a Cajun surf 'n turf taco
#
# 257
# 00:10:20,786 --> 00:10:22,656
# with braised white fish
# and bacon.
#
# 258
# 00:10:23,522 --> 00:10:25,162
# Ready, y'all.
# Let's go.
#
# 259
# 00:10:25,157 --> 00:10:26,487
# Hi, my name is Matt.
#
# 260
# 00:10:26,492 --> 00:10:29,362
# I'm calling from
# the Let There Be Bacon truck,
#
# 261
# 00:10:29,362 --> 00:10:31,162
# and we're coming into Mobile
# this weekend
#
# 262
# 00:10:31,163 --> 00:10:33,673
# and we would really like to set
# up in front of your bar there.
#
# 263
# 00:10:33,666 --> 00:10:36,466
# Mobile's a really small city,
# and Dauphin Street
#
# 264
# 00:10:36,469 --> 00:10:38,969
# is the place to be, so we found
# a hot little beer garden there.
#
# 265
# 00:10:38,971 --> 00:10:40,111
# We're going to partner up
#
# 266
# 00:10:40,106 --> 00:10:42,066
# and we're going to kill it
# on social media,
#
# 267
# 00:10:42,074 --> 00:10:44,384
# and it should bring
# a lot of people to the truck.
#
# 268
# 00:10:44,377 --> 00:10:46,807
# Watch it.
#
# 269
# 00:10:46,812 --> 00:10:49,552
# There's easily the biggest crowd
# we've had in any city so far.
#
# 270
# 00:10:49,548 --> 00:10:50,878
# It is really important
# that we hammer
#
# 271
# 00:10:50,883 --> 00:10:52,323
# through our prep
# as quickly as possible.
#
# 272
# 00:10:52,318 --> 00:10:54,118
# Everybody's hungry out there.
# Let's chop the shrimp,
#
# 273
# 00:10:54,120 --> 00:10:56,320
# get it in buttermilk,
# and we'll get open.
#
# 274
# 00:10:56,322 --> 00:11:00,532
# Hi, this is Rachel with
# the Lone Star Chuck Wagon.
#
# 275
# 00:11:00,526 --> 00:11:03,656
# We'd like to partner up with you
# if you're interested.
#
# 276
# 00:11:03,662 --> 00:11:06,132
# Hayley's Bar is
# the hottest spot in town.
#
# 277
# 00:11:06,132 --> 00:11:09,172
# We're going to get the best spot
# and we're going to win Alabama.
#
# 278
# 00:11:09,168 --> 00:11:10,898
# Those are going to be
# peeled completely off,
#
# 279
# 00:11:10,903 --> 00:11:12,913
# the tail and everything.
#
# 280
# 00:11:12,905 --> 00:11:14,035
# I'm worried that our prep
#
# 281
# 00:11:14,040 --> 00:11:15,710
# is going to take
# longer than normal.
#
# 282
# 00:11:15,708 --> 00:11:17,408
# We have all this
# beautiful shrimp,
#
# 283
# 00:11:17,410 --> 00:11:19,050
# but we have to
# take away from our
#
# 284
# 00:11:19,045 --> 00:11:21,275
# regular prep to peel
# all these damn shrimp.
#
# 285
# 00:11:21,280 --> 00:11:23,520
# Let's do this,
# girls.
#
# 286
# 00:11:23,516 --> 00:11:26,586
# Hi, Carol.
# We are on our way.
#
# 287
# 00:11:26,585 --> 00:11:29,015
# We have parking
# and everything?
#
# 288
# 00:11:29,021 --> 00:11:31,391
# Yes.
# Thank you.
#
# 289
# 00:11:31,390 --> 00:11:33,730
# Middle Feast got
# the perfect location,
#
# 290
# 00:11:33,726 --> 00:11:36,496
# between Lone Star and Bacon.
#
# 291
# 00:11:36,495 --> 00:11:38,525
# That way I can look
# at my competition
#
# 292
# 00:11:38,531 --> 00:11:40,431
# and I'm right there
# in the middle.
#
# 293
# 00:11:40,433 --> 00:11:42,273
# Everybody knows what
# they need to do, right?
#
# 294
# 00:11:42,268 --> 00:11:43,998
# Yes, sir.
# Let's do it.
#
# 295
# 00:11:44,003 --> 00:11:45,373
# All right, everybody,
#
# 296
# 00:11:45,371 --> 00:11:47,611
# we're ready and open
# for business!
#
# 297
# 00:11:49,341 --> 00:11:51,411
# I'm a little worried
#
# 298
# 00:11:51,410 --> 00:11:53,480
# these shrimp are
# the new snakebites ââ
#
# 299
# 00:11:53,479 --> 00:11:54,679
# delicious,
#
# 300
# 00:11:54,680 --> 00:11:58,850
# but too timeâconsuming
# for contest mode.
#
# 301
# 00:11:58,851 --> 00:12:02,321
# Our line is around the corner.
#
# 302
# 00:12:02,321 --> 00:12:05,691
# All right, Mobile,
# we are ready!
#
# 303
# 00:12:05,691 --> 00:12:07,031
# This is intimidating.
#
# 304
# 00:12:07,026 --> 00:12:09,556
# I don't know what
# we're going to do.
#
# 305
# 00:12:09,562 --> 00:12:11,002
# I have a bowl for Christy.
#
# 306
# 00:12:10,996 --> 00:12:13,866
# Shawn, quesadilla in a bowl.
#
# 307
# 00:12:13,866 --> 00:12:15,366
# Matt, Rene!
#
# 308
# 00:12:15,367 --> 00:12:17,097
# We have to have
# three seafood dishes,
#
# 309
# 00:12:17,103 --> 00:12:19,213
# but we're definitely
# going to keep our TexâMex
#
# 310
# 00:12:19,205 --> 00:12:21,465
# steak quesadilla
# at 15 bucks.
#
# 311
# 00:12:21,474 --> 00:12:24,244
# Also a surf 'n turf bowl.
# That's going to be 10 bucks.
#
# 312
# 00:12:24,243 --> 00:12:25,743
# For our wrap,
# we're going to
#
# 313
# 00:12:25,744 --> 00:12:27,954
# take out the chicken
# and add barbecue shrimp.
#
# 314
# 00:12:27,947 --> 00:12:30,217
# Quesadilla and your wrap.
#
# 315
# 00:12:30,216 --> 00:12:32,486
# These shrimp are beautiful,
# but we still have to
#
# 316
# 00:12:32,485 --> 00:12:34,045
# peel them all
# and deâvein them.
#
# 317
# 00:12:34,053 --> 00:12:35,223
# To save time and work,
#
# 318
# 00:12:35,221 --> 00:12:36,991
# we're going to have
# a peel and eat option,
#
# 319
# 00:12:36,989 --> 00:12:40,059
# with a jalapeÃ±o garlic butter,
# toss a little bit of hot sauce.
#
# 320
# 00:12:40,059 --> 00:12:41,329
# Delish.
#
# 321
# 00:12:41,327 --> 00:12:43,257
# Jessica!
#
# 322
# 00:12:43,262 --> 00:12:45,332
# Here's your quesadilla, miss.
#
# 323
# 00:12:49,635 --> 00:12:51,965
# We've lost
# a lot of people.
#
# 324
# 00:12:51,971 --> 00:12:53,711
# Just want you to be aware.
#
# 325
# 00:12:53,706 --> 00:12:55,976
# Cleaning and deâveining
# 15 pounds of thickâshelled
#
# 326
# 00:12:55,975 --> 00:12:58,105
# Gulf shrimp,
# it takes a long time.
#
# 327
# 00:12:58,110 --> 00:13:00,350
# People are walking out of our
# line and going to Middle Feast.
#
# 328
# 00:13:00,346 --> 00:13:02,646
# It's becoming
# insanely frustrating.
#
# 329
# 00:13:02,648 --> 00:13:03,978
# You all right?
#
# 330
# 00:13:03,983 --> 00:13:05,053
# I can't ââ
#
# 331
# 00:13:05,050 --> 00:13:07,350
# I can't stop shaking,
# and I can't ââ
#
# 332
# 00:13:07,353 --> 00:13:09,493
# Hey, look at me,
# look at me.
#
# 333
# 00:13:09,488 --> 00:13:10,888
# Take it easy, Bubba.
#
# 334
# 00:13:10,890 --> 00:13:12,120
# Hey, look at me.
#
# 335
# 00:13:12,124 --> 00:13:13,794
# You're good,
# you're good.
#
# 336
# 00:13:13,792 --> 00:13:15,092
# You're good.
#
# 337
# 00:13:15,094 --> 00:13:17,004
# Look right at me.
# Take a deep breath.
#
# 338
# 00:13:16,996 --> 00:13:19,866
# Breathe in through your nose,
# breathe out through your mouth.
#
# 339
# 00:13:19,865 --> 00:13:20,965
# Matt's hands are shaking,
#
# 340
# 00:13:20,966 --> 00:13:22,496
# the color's drained
# from his face,
#
# 341
# 00:13:22,501 --> 00:13:24,641
# his respirations
# have increased,
#
# 342
# 00:13:24,637 --> 00:13:26,107
# and I'm really,
# really worried.
#
# 343
# 00:13:26,105 --> 00:13:27,665
# I'm about to have ââ
# have a panic attack.
#
# 344
# 00:13:27,673 --> 00:13:29,113
# Take a deep breath.
#
# 345
# 00:13:29,108 --> 00:13:31,238
# You're going to be
# fine with this.
#
# 346
# 00:13:31,243 --> 00:13:32,483
# All right?
# You got this.
#
# 347
# 00:13:32,478 --> 00:13:33,748
# Take a deep breath.
#
# 348
# 00:13:33,746 --> 00:13:35,146
# Matt was real anxious.
#
# 349
# 00:13:35,147 --> 00:13:37,077
# It's daunting to
# look out at
#
# 350
# 00:13:37,082 --> 00:13:39,622
# all of those people
# standing in line.
#
# 351
# 00:13:39,618 --> 00:13:41,618
# You got this.
# You got this, homey.
#
# 352
# 00:13:46,192 --> 00:13:49,532
# So one salmon
# and one water.
#
# 353
# 00:13:49,528 --> 00:13:52,028
# This is the biggest line
# we've ever had. Crazy.
#
# 354
# 00:13:52,031 --> 00:13:54,201
# This is what we've
# been waiting for
#
# 355
# 00:13:54,200 --> 00:13:55,570
# the whole competition.
#
# 356
# 00:13:55,568 --> 00:13:58,838
# Not having shrimps in our
# food truck is the best decision.
#
# 357
# 00:13:58,837 --> 00:14:00,237
# We don't need to
# prep the shrimp,
#
# 358
# 00:14:00,239 --> 00:14:01,669
# we don't need
# to peel the shrimp.
#
# 359
# 00:14:01,674 --> 00:14:04,414
# Two fish
# and two small shawarmas.
#
# 360
# 00:14:04,410 --> 00:14:06,650
# Our line is really long
# and we're not
#
# 361
# 00:14:06,645 --> 00:14:08,205
# getting out food very fast.
#
# 362
# 00:14:08,214 --> 00:14:10,924
# Still peeling shrimp,
# my back hurts.
#
# 363
# 00:14:10,916 --> 00:14:11,916
# I don't care.
#
# 364
# 00:14:11,917 --> 00:14:13,317
# I'll do anything
# for the team.
#
# 365
# 00:14:13,319 --> 00:14:15,619
# Rachel's still peeling
# and deâveining
#
# 366
# 00:14:15,621 --> 00:14:16,661
# endless shrimp.
#
# 367
# 00:14:16,655 --> 00:14:19,325
# It's on our menu
# and we have to serve it,
#
# 368
# 00:14:19,325 --> 00:14:20,655
# and it's kind of a nightmare.
#
# 369
# 00:14:20,659 --> 00:14:22,159
# This should be
# in the contest,
#
# 370
# 00:14:22,161 --> 00:14:23,501
# who can peel 100 pounds
# worth of shrimp.
#
# 371
# 00:14:23,495 --> 00:14:25,795
# Our efficiency has plummeted.
#
# 372
# 00:14:25,798 --> 00:14:27,698
# Andrea has to
# leave the window,
#
# 373
# 00:14:27,700 --> 00:14:30,040
# have guests waiting
# while she helps prep.
#
# 374
# 00:14:30,035 --> 00:14:31,865
# This is not the way
# we want this to go.
#
# 375
# 00:14:31,870 --> 00:14:34,270
# We were hoping people will buy
# peel 'n eat shrimp,
#
# 376
# 00:14:34,273 --> 00:14:37,643
# but they're buying the shrimp
# that we have to peel ourselves,
#
# 377
# 00:14:37,643 --> 00:14:39,043
# but such is life.
#
# 378
# 00:14:39,044 --> 00:14:42,284
# I'm going to go out there,
# sing a song.
#
# 379
# 00:14:42,281 --> 00:14:44,681
# I know you've got this.
# Stay positive.
#
# 380
# 00:14:51,624 --> 00:14:53,834
# I thought that he might not
# be able to go any further,
#
# 381
# 00:14:53,826 --> 00:14:55,326
# but he really showed me
# his true colors.
#
# 382
# 00:14:55,327 --> 00:14:56,597
# I'm really proud of that kid.
#
# 383
# 00:14:59,098 --> 00:15:00,298
# Or you.
#
# 384
# 00:15:02,167 --> 00:15:03,697
# It took us two hours
# to open our doors,
#
# 385
# 00:15:03,702 --> 00:15:04,872
# so now we
# have to make sure
#
# 386
# 00:15:04,870 --> 00:15:06,770
# food is flying
# out of this kitchen.
#
# 387
# 00:15:06,772 --> 00:15:08,872
# I hope those guys are ready
# for the barrage of tickets
#
# 388
# 00:15:08,874 --> 00:15:09,944
# I'm about to send their way.
#
# 389
# 00:15:09,942 --> 00:15:13,152
# Lafayette,
# two po' boys, two tacos.
#
# 390
# 00:15:13,145 --> 00:15:14,505
# Order up for John S.
#
# 391
# 00:15:14,513 --> 00:15:15,513
# Here you go, brother.
#
# 392
# 00:15:15,514 --> 00:15:17,024
# Thanks for being
# patient with us.
#
# 393
# 00:15:17,016 --> 00:15:19,346
# How you guys doing?
# Hello!
#
# 394
# 00:15:19,351 --> 00:15:21,521
# Good to see you,
# how you doing?
#
# 395
# 00:15:21,520 --> 00:15:23,420
# Lone Star,
# how you guys doing?
# Hi, Tyler.
#
# 396
# 00:15:23,422 --> 00:15:25,762
# I never know what to expect
# when I see Tyler.
#
# 397
# 00:15:25,758 --> 00:15:26,958
# I'm scared.
#
# 398
# 00:15:26,959 --> 00:15:28,829
# I want you guys to close up
# at 9:00 tonight.
#
# 399
# 00:15:28,827 --> 00:15:30,297
# I want you fresh and rested.
#
# 400
# 00:15:30,296 --> 00:15:32,326
# Mobile is a really
# big brunch town.
#
# 401
# 00:15:32,331 --> 00:15:34,171
# It's a chance to make a lot
# of money tomorrow morning.
#
# 402
# 00:15:34,166 --> 00:15:36,796
# We're going to have
# a bracketâstyle cookâoff.
#
# 403
# 00:15:36,802 --> 00:15:38,902
# I'm going to judge
# everybody's brunch dish,
#
# 404
# 00:15:38,904 --> 00:15:41,014
# and the best two teams
#
# 405
# 00:15:41,006 --> 00:15:43,576
# are going to be eligible
# for the big seafood cookâoff
#
# 406
# 00:15:43,575 --> 00:15:44,675
# later in the afternoon,
#
# 407
# 00:15:44,677 --> 00:15:46,707
# and the grand prize
# is going to be $1,000.
#
# 408
# 00:15:46,712 --> 00:15:48,612
# I can't even tell you
# how excited I am about this.
#
# 409
# 00:15:48,614 --> 00:15:49,984
# I love cooking brunch.
#
# 410
# 00:15:49,982 --> 00:15:52,182
# I've cooked it in most of
# the restaurants I've worked at.
#
# 411
# 00:15:52,184 --> 00:15:54,654
# Tomorrow night, I'm going to
# judge your best seafood dish.
#
# 412
# 00:15:54,653 --> 00:15:57,223
# The winner of that competition
# is going to get $1,000.
#
# 413
# 00:15:57,222 --> 00:15:59,762
# 1,000 bucks
# is a lot of money.
#
# 414
# 00:15:59,758 --> 00:16:02,628
# Plus we've never won
# a challenge before,
#
# 415
# 00:16:02,628 --> 00:16:04,328
# so we really want to
# win this challenge.
#
# 416
# 00:16:04,330 --> 00:16:06,270
# Good to see you guys.
# Bye, guys, thanks so much.
#
# 417
# 00:16:06,265 --> 00:16:07,265
# See you tomorrow, okay?
#
# 418
# 00:16:07,266 --> 00:16:09,496
# Give it up for Chef!
#
# 419
# 00:16:09,501 --> 00:16:12,811
# We really need to win
# this challenge tomorrow, guys.
#
# 420
# 00:16:12,805 --> 00:16:15,735
# We've never needed to win
# a challenge so badly.
#
# 421
# 00:16:15,741 --> 00:16:16,981
# I mean, winning $1,000,
#
# 422
# 00:16:16,975 --> 00:16:19,775
# that could easily push us
# to where we need to be.
#
# 423
# 00:16:19,778 --> 00:16:21,408
# Just going to close up,
# get ready for tomorrow.
#
# 424
# 00:16:21,413 --> 00:16:22,453
# We've got a brunch dish to do.
#
# 425
# 00:16:23,515 --> 00:16:24,515
# Let's go.
#
# 426
# 00:16:28,220 --> 00:16:30,860
# - Let's go.
# - All right.
#
# 427
# 00:16:30,856 --> 00:16:32,286
# Day 2 in Mobile
# is just beginning,
#
# 428
# 00:16:32,291 --> 00:16:34,461
# and our teams are dealing
# with the challenge
#
# 429
# 00:16:34,460 --> 00:16:36,900
# of adding a brunch dish
# to their menus.
#
# 430
# 00:16:36,895 --> 00:16:38,195
# I think shrimp and grits
# are going to be tasty.
#
# 431
# 00:16:38,197 --> 00:16:40,397
# After
# a shopping trip for grits,
#
# 432
# 00:16:40,399 --> 00:16:41,499
# Let There Be Bacon is back
#
# 433
# 00:16:41,500 --> 00:16:43,070
# parked in front of
# the beer garden.
#
# 434
# 00:16:43,068 --> 00:16:45,498
# Okay, guys, prep's been
# going for an hour and a half.
#
# 435
# 00:16:45,504 --> 00:16:47,974
# Let's see what they have
# in the butchery first.
#
# 436
# 00:16:47,973 --> 00:16:50,643
# Planning for success,
# Lone Star shopped for both
#
# 437
# 00:16:50,642 --> 00:16:53,352
# their brunch dish and something
# for the seafood challenge.
#
# 438
# 00:16:53,345 --> 00:16:54,605
# What local fish
# is there here?
#
# 439
# 00:16:54,613 --> 00:16:55,713
# Grouper.
# Okay.
#
# 440
# 00:16:55,714 --> 00:16:57,384
# They hope
# the expensive fish
#
# 441
# 00:16:57,383 --> 00:16:58,953
# will win them
# the seafood cookâoff.
#
# 442
# 00:16:58,951 --> 00:17:01,091
# You guys have like,
# local sausage?
#
# 443
# 00:17:01,086 --> 00:17:02,686
# Yeah, we have
# a Conecuh sausage.
# Great.
#
# 444
# 00:17:02,688 --> 00:17:05,518
# We have stock from yesterday,
# so we can start selling already.
#
# 445
# 00:17:05,524 --> 00:17:07,434
# After a quick
# shopping trip,
#
# 446
# 00:17:07,426 --> 00:17:11,496
# Middle Feast has also returned
# to yesterday's parking spot.
#
# 447
# 00:17:11,497 --> 00:17:14,267
# All right, everybody!
# We're open! Woo!
#
# 448
# 00:17:14,266 --> 00:17:16,266
# That sounds like
# Middle Feast is open.
#
# 449
# 00:17:16,268 --> 00:17:17,668
# I just heard the crowd.
#
# 450
# 00:17:17,669 --> 00:17:20,139
# How do these guys get
# their doors open so fast, man?
#
# 451
# 00:17:20,139 --> 00:17:22,109
# No idea.
#
# 452
# 00:17:22,107 --> 00:17:23,477
# No idea.
#
# 453
# 00:17:23,475 --> 00:17:25,775
# Preâservice is kind of
# a Catchâ22 for us.
#
# 454
# 00:17:25,778 --> 00:17:27,378
# If we take too much time
#
# 455
# 00:17:27,379 --> 00:17:29,549
# prepping,
# then our service suffers
#
# 456
# 00:17:29,548 --> 00:17:32,318
# because we're not open
# for long enough.
#
# 457
# 00:17:32,317 --> 00:17:33,717
# But if I don't
# prep enough food,
#
# 458
# 00:17:33,719 --> 00:17:35,349
# then our service suffers
# in the middle
#
# 459
# 00:17:35,354 --> 00:17:38,194
# because we have to prep out food
# during the middle of service.
#
# 460
# 00:17:38,190 --> 00:17:40,530
# Love it if we can have
# this open by noon, guys.
#
# 461
# 00:17:40,526 --> 00:17:43,526
# That'll be $32.
#
# 462
# 00:17:43,529 --> 00:17:45,559
# Not like yesterday,
# It's still good,
#
# 463
# 00:17:45,564 --> 00:17:48,304
# and it's just getting
# better and better.
#
# 464
# 00:17:48,300 --> 00:17:50,870
# Even though we don't have
# the same lines as yesterday,
#
# 465
# 00:17:50,869 --> 00:17:52,869
# the tickets are just coming in,
#
# 466
# 00:17:52,871 --> 00:17:56,141
# the food is flying out.
# We're busy.
#
# 467
# 00:17:56,141 --> 00:17:58,211
# Thank you so much, guys.
#
# 468
# 00:17:58,210 --> 00:17:59,750
# Today we're adding
# the brunch item,
#
# 469
# 00:17:59,745 --> 00:18:00,945
# the shakshouka.
#
# 470
# 00:18:00,946 --> 00:18:03,716
# Shakshouka is
# a tomatoâbased sauce,
#
# 471
# 00:18:03,715 --> 00:18:06,615
# heavily spiced,
# with peppers, onions,
#
# 472
# 00:18:06,618 --> 00:18:08,788
# and it's going to come
# with eggs poached inside.
#
# 473
# 00:18:08,787 --> 00:18:11,587
# We're going to serve it
# on toasted garlic bread
#
# 474
# 00:18:11,590 --> 00:18:13,160
# with some kale underneath,
#
# 475
# 00:18:13,158 --> 00:18:14,728
# and a little bit
# of feta cheese,
#
# 476
# 00:18:14,726 --> 00:18:16,756
# just to cool it down a little.
#
# 477
# 00:18:16,762 --> 00:18:18,032
# The shakshouka.
#
# 478
# 00:18:18,030 --> 00:18:21,770
# All right, Mobile!
# Lone Star Chuck Wagon
#
# 479
# 00:18:21,767 --> 00:18:23,097
# is open for business!
#
# 480
# 00:18:23,101 --> 00:18:24,871
# Come eat some delicious food!
#
# 481
# 00:18:26,505 --> 00:18:29,735
# This is
# the Conecuh sausage
#
# 482
# 00:18:29,741 --> 00:18:32,911
# we well as some
# alligator sausage.
#
# 483
# 00:18:32,911 --> 00:18:34,911
# I'm just going to actually
# cut 'em all altogether
#
# 484
# 00:18:34,913 --> 00:18:35,913
# and blend it up.
#
# 485
# 00:18:35,914 --> 00:18:37,224
# For our brunch dish,
#
# 486
# 00:18:37,216 --> 00:18:39,786
# we're going to use some of
# our TexâMex ingredients
#
# 487
# 00:18:39,785 --> 00:18:42,245
# to make a beautiful
# brunch taquito.
#
# 488
# 00:18:42,254 --> 00:18:43,764
# We're also going to do
#
# 489
# 00:18:43,755 --> 00:18:45,415
# our beautiful
# grilled grouper,
#
# 490
# 00:18:45,424 --> 00:18:47,994
# which are going to sell
# for $40.
#
# 491
# 00:18:47,993 --> 00:18:50,103
# Delicious.
# We want to set
#
# 492
# 00:18:50,095 --> 00:18:52,055
# a high price point
# so we can put
#
# 493
# 00:18:52,064 --> 00:18:54,104
# as much money into
# our cash box as possible.
#
# 494
# 00:18:54,099 --> 00:18:56,129
# What can I get
# for you today, sir?
#
# 495
# 00:18:56,134 --> 00:18:57,244
# Sure.
#
# 496
# 00:18:57,236 --> 00:18:58,466
# Lance, grouper.
#
# 497
# 00:18:58,470 --> 00:19:01,340
# Does anyone know
# where the grouper is?
#
# 498
# 00:19:01,340 --> 00:19:03,740
# I need to
# find the fish.
#
# 499
# 00:19:03,742 --> 00:19:05,582
# I have big plans
# for this grouper,
#
# 500
# 00:19:05,577 --> 00:19:07,007
# and I can't find it anywhere.
#
# 501
# 00:19:07,012 --> 00:19:09,252
# Okay, so it's
# not in here.
#
# 502
# 00:19:09,248 --> 00:19:11,648
# Now we can't make
# this beautiful grouper dish
#
# 503
# 00:19:11,650 --> 00:19:13,520
# for the cooking challenge,
#
# 504
# 00:19:13,519 --> 00:19:17,189
# and what's worse is we can't
# sell our $40 grouper anymore.
#
# 505
# 00:19:17,189 --> 00:19:18,519
# This is bad.
#
# 506
# 00:19:18,524 --> 00:19:19,834
# Give me one moment, sir.
#
# 507
# 00:19:19,825 --> 00:19:21,455
# We're searching frantically
# for the grouper.
#
# 508
# 00:19:21,460 --> 00:19:25,000
# We are checking the car,
# and then it occurs to me
#
# 509
# 00:19:24,997 --> 00:19:28,427
# that we never even
# went back for it.
#
# 510
# 00:19:28,433 --> 00:19:30,103
# It's not even on the receipt.
#
# 511
# 00:19:30,102 --> 00:19:31,302
# We never brought it.
#
# 512
# 00:19:31,303 --> 00:19:32,603
# We can make the same dish.
#
# 513
# 00:19:32,604 --> 00:19:34,074
# We can do it
# with the tilapia.
#
# 514
# 00:19:34,072 --> 00:19:35,272
# The same dish? Okay.
#
# 515
# 00:19:35,274 --> 00:19:38,944
# We can't charge
# that much for tilapia.
#
# 516
# 00:19:38,944 --> 00:19:41,514
# Uh, we'll give
# you 10 bucks back?
#
# 517
# 00:19:41,513 --> 00:19:43,483
# $10, so it's $30?
# Okay.
#
# 518
# 00:19:43,482 --> 00:19:46,052
# You know,
# we're in the South,
#
# 519
# 00:19:46,051 --> 00:19:48,151
# shrimp and grits
# is a big Southern dish,
#
# 520
# 00:19:48,153 --> 00:19:50,793
# and we hope that people are
# going to enjoy eating it
#
# 521
# 00:19:50,789 --> 00:19:52,319
# as much as we enjoy cooking it.
#
# 522
# 00:19:52,324 --> 00:19:54,394
# We have to win
# this taste challenge.
#
# 523
# 00:19:55,394 --> 00:19:57,034
# So for brunch,
#
# 524
# 00:19:57,029 --> 00:19:59,499
# we decided to go with
# a cheesy maple bacon grits.
#
# 525
# 00:19:59,498 --> 00:20:00,528
# Out the door.
#
# 526
# 00:20:00,532 --> 00:20:02,732
# Grilled shrimp on top,
# peppers, onions,
#
# 527
# 00:20:02,734 --> 00:20:05,804
# maple brown sugar, simple syrup
# over the top of the shrimp.
#
# 528
# 00:20:05,804 --> 00:20:08,044
# I really feel like we've got
# this challenge in the bag.
#
# 529
# 00:20:08,040 --> 00:20:11,010
# Let's get stuff
# portioned out for Tyler,
#
# 530
# 00:20:11,009 --> 00:20:12,709
# make sure that we have
# portions put aside
#
# 531
# 00:20:12,711 --> 00:20:14,151
# for the cooking challenge
# itself.
#
# 532
# 00:20:17,849 --> 00:20:19,989
# Tyler should call
# probably pretty soon.
#
# 533
# 00:20:19,985 --> 00:20:21,445
# He didn't call us today yet.
#
# 534
# 00:20:21,453 --> 00:20:24,063
# So I'm assuming it's going
# to be like really soon.
#
# 535
# 00:20:24,056 --> 00:20:26,186
# Hi.
# Hi.
#
# 536
# 00:20:26,191 --> 00:20:27,391
# Will you do me a favor?
#
# 537
# 00:20:27,392 --> 00:20:28,962
# These guys are right
# in the middle of
#
# 538
# 00:20:28,961 --> 00:20:30,631
# a cooking contest
# for the best brunch dish
#
# 539
# 00:20:30,629 --> 00:20:33,629
# and I don't want them
# to know that it's me.
#
# 540
# 00:20:33,632 --> 00:20:35,572
# Will you be
# my private shopper?
# I'm your girl.
#
# 541
# 00:20:35,567 --> 00:20:37,137
# So, I'm going to buy
# you guys brunch today.
#
# 542
# 00:20:37,135 --> 00:20:38,265
# Perfect.
# Perfect.
#
# 543
# 00:20:38,270 --> 00:20:41,140
# But just do me a favor,
# buy two brunch specials.
#
# 544
# 00:20:41,139 --> 00:20:43,009
# See that restaurant right across
# the street, that balcony?
#
# 545
# 00:20:43,008 --> 00:20:44,938
# Yeah.
# Meet me up there.
#
# 546
# 00:20:44,943 --> 00:20:47,113
# And then we'll eat together
# and tell me what you think.
#
# 547
# 00:20:47,112 --> 00:20:48,312
# I'm excited.
#
# 548
# 00:20:48,313 --> 00:20:49,753
# All right, your code name
# is Florence.
#
# 549
# 00:20:49,748 --> 00:20:50,748
# I'm Florence.
#
# 550
# 00:20:50,749 --> 00:20:52,989
# Thank you very much.
#
# 551
# 00:20:52,985 --> 00:20:54,845
# Um, wasn't there supposed to be
#
# 552
# 00:20:54,853 --> 00:20:56,693
# a brunch challenge today
# or something?
#
# 553
# 00:20:56,688 --> 00:20:57,788
# What can I get for you?
#
# 554
# 00:20:57,789 --> 00:20:59,189
# Can I get two brunches?
#
# 555
# 00:20:59,191 --> 00:21:00,361
# Sure.
# What's the name?
#
# 556
# 00:21:00,359 --> 00:21:01,629
# Ty.
# Ty?
#
# 557
# 00:21:01,627 --> 00:21:02,957
# We're having
# a really busy morning,
#
# 558
# 00:21:02,961 --> 00:21:04,501
# and I'm wondering when
# this brunch challenge
#
# 559
# 00:21:04,496 --> 00:21:05,496
# is actually going to happen.
#
# 560
# 00:21:05,497 --> 00:21:07,527
# Can I get
# two shakshouka, please?
#
# 561
# 00:21:07,532 --> 00:21:09,002
# Two shakshoukas?
# Yeah.
#
# 562
# 00:21:09,001 --> 00:21:10,401
# Hi.
#
# 563
# 00:21:10,402 --> 00:21:11,702
# Two of your
# brunch specials,
#
# 564
# 00:21:11,703 --> 00:21:12,703
# the shrimp and grits.
#
# 565
# 00:21:12,704 --> 00:21:13,714
# Two of the grits?
# Yes.
#
# 566
# 00:21:13,705 --> 00:21:15,305
# Tyler came by
# a while ago
#
# 567
# 00:21:15,307 --> 00:21:16,707
# and I haven't seen him since.
#
# 568
# 00:21:16,708 --> 00:21:17,708
# What's going on?
#
# 569
# 00:21:17,709 --> 00:21:19,309
# I have an order for Ty.
#
# 570
# 00:21:19,311 --> 00:21:21,681
# Florence?
# Thank you.
#
# 571
# 00:21:21,680 --> 00:21:23,420
# Can't wait to try it.
#
# 572
# 00:21:23,415 --> 00:21:24,975
# How you doing?
# Hey, how you doing?
#
# 573
# 00:21:24,983 --> 00:21:26,253
# Okay, good.
# How you doing?
#
# 574
# 00:21:26,251 --> 00:21:28,621
# What did you order?
# What's the name of the dish?
#
# 575
# 00:21:28,620 --> 00:21:29,660
# The Texabama Taquito.
#
# 576
# 00:21:29,655 --> 00:21:30,855
# Texabama Taquito.
#
# 577
# 00:21:30,856 --> 00:21:32,786
# So this is Lone Star
# Chuck Wagon, obviously.
#
# 578
# 00:21:32,791 --> 00:21:34,591
# Right.
# Let's try it.
#
# 579
# 00:21:37,496 --> 00:21:39,096
# I think these are tasty.
#
# 580
# 00:21:39,097 --> 00:21:40,327
# I think it's good.
#
# 581
# 00:21:40,332 --> 00:21:44,102
# So, shrimp and grits,
# a really good Southern dish.
#
# 582
# 00:21:44,102 --> 00:21:47,212
# The bacon is a twist.
# That's their trademark.
#
# 583
# 00:21:47,205 --> 00:21:48,205
# The shrimp's wellâcooked,
#
# 584
# 00:21:48,206 --> 00:21:50,036
# but the peppers,
# the green onions,
#
# 585
# 00:21:50,042 --> 00:21:51,812
# that's all classic
# shrimp and grits.
#
# 586
# 00:21:51,810 --> 00:21:52,980
# I think they're
# cooking locally,
#
# 587
# 00:21:52,978 --> 00:21:54,948
# which was what
# the challenge was this week,
#
# 588
# 00:21:54,946 --> 00:21:57,976
# make sure you really kind of
# understand the clientele
#
# 589
# 00:21:57,983 --> 00:21:59,523
# and pull in
# their philosophy.
#
# 590
# 00:21:59,518 --> 00:22:01,818
# I think they're embracing
# the idea of Mobile.
#
# 591
# 00:22:02,854 --> 00:22:04,164
# What is this dish called?
#
# 592
# 00:22:04,156 --> 00:22:05,686
# Shakshouka.
# It's different.
#
# 593
# 00:22:05,691 --> 00:22:07,231
# It's nice,
# it's good.
#
# 594
# 00:22:07,225 --> 00:22:08,355
# This is great.
#
# 595
# 00:22:08,360 --> 00:22:10,400
# Overall, it's pretty fancy
# for a food truck.
#
# 596
# 00:22:10,395 --> 00:22:12,455
# And this is something you'd
# definitely order again?
#
# 597
# 00:22:12,464 --> 00:22:14,204
# Yeah.
# All right, cool.
#
# 598
# 00:22:14,199 --> 00:22:15,399
# Thank you very much.
#
# 599
# 00:22:15,400 --> 00:22:17,770
# How are we doing on food,
# Arkadi?
#
# 600
# 00:22:17,769 --> 00:22:19,909
# We're actually running
# out of food,
#
# 601
# 00:22:19,905 --> 00:22:21,205
# which is a good thing,
#
# 602
# 00:22:21,206 --> 00:22:23,406
# but I still don't think
# we need to go shopping.
#
# 603
# 00:22:23,408 --> 00:22:25,408
# So we're just going to sell
# whatever we have?
#
# 604
# 00:22:25,410 --> 00:22:27,810
# Sell whatever we have.
# This is our last day over here.
#
# 605
# 00:22:27,813 --> 00:22:29,413
# As we run out of product,
#
# 606
# 00:22:29,414 --> 00:22:33,424
# we're knocking off
# menu items one by one,
#
# 607
# 00:22:33,418 --> 00:22:35,318
# and I think it's
# the smart thing to do,
#
# 608
# 00:22:35,320 --> 00:22:36,920
# just change
# the menu as it goes
#
# 609
# 00:22:36,922 --> 00:22:38,462
# and not go shopping again.
#
# 610
# 00:22:38,457 --> 00:22:40,827
# So we have only two things
# on our menu.
#
# 611
# 00:22:40,826 --> 00:22:43,456
# We have the standard shawarma
# and the nachos.
#
# 612
# 00:22:43,462 --> 00:22:45,132
# So let's sell
# shawarma and nachos.
#
# 613
# 00:22:45,130 --> 00:22:46,130
# Shawarma and nachos.
#
# 614
# 00:22:46,131 --> 00:22:47,131
# Until the end.
#
# 615
# 00:22:47,132 --> 00:22:48,672
# We sold out of shrimp.
#
# 616
# 00:22:48,667 --> 00:22:51,837
# So we need at least food
# for the cooking challenge.
#
# 617
# 00:22:51,837 --> 00:22:54,237
# I think if there's
# a local market around here
#
# 618
# 00:22:54,239 --> 00:22:56,069
# we can hit up
# for just shrimp...
#
# 619
# 00:22:56,074 --> 00:22:58,344
# Southern Fish & Oyster.
# It says they're
# open till 5:00.
#
# 620
# 00:22:58,343 --> 00:23:00,283
# We're going to go to
# a local seafood place.
#
# 621
# 00:23:00,278 --> 00:23:01,348
# It's less than a mile away,
#
# 622
# 00:23:01,346 --> 00:23:03,876
# it's going to save us
# a bunch of time,
#
# 623
# 00:23:03,882 --> 00:23:05,582
# and we're going to be
# able to get back
#
# 624
# 00:23:05,584 --> 00:23:07,854
# and open the doors
# and start selling again.
#
# 625
# 00:23:11,623 --> 00:23:12,723
# I don't know.
#
# 626
# 00:23:12,724 --> 00:23:14,634
# Doesn't look like
# it's open.
#
# 627
# 00:23:14,626 --> 00:23:17,256
# They're closed during
# their regular business hours.
#
# 628
# 00:23:17,262 --> 00:23:19,702
# Now we have to go back out
# to the other grocery store
#
# 629
# 00:23:19,698 --> 00:23:21,028
# Now we have to go back out
# to the other grocery store
#
# 630
# 00:23:21,032 --> 00:23:22,872
# that's further away and double
# back across our position.
#
# 631
# 00:23:22,868 --> 00:23:25,068
# This time management thing
# is not on our side right now.
#
# 632
# 00:23:25,070 --> 00:23:27,940
# Well, that stinks.
#
# 633
# 00:23:31,710 --> 00:23:33,210
# Thanks so much, y'all, enjoy.
#
# 634
# 00:23:33,211 --> 00:23:35,951
# It's Day 2 in Mobile,
# and our teams are waiting for me
#
# 635
# 00:23:35,947 --> 00:23:37,777
# to judge their brunch dishes.
#
# 636
# 00:23:37,783 --> 00:23:40,093
# Maybe no news is bad news.
#
# 637
# 00:23:40,085 --> 00:23:41,045
# What they
# don't know is that
#
# 638
# 00:23:41,052 --> 00:23:42,392
# I've already
# tasted their food.
#
# 639
# 00:23:42,387 --> 00:23:44,217
# I think they're doing
# a really great job with this.
#
# 640
# 00:23:44,222 --> 00:23:45,892
# After a busy morning,
# Lone Star and Middle Feast's
#
# 641
# 00:23:45,891 --> 00:23:47,591
# crowds have thinned out
#
# 642
# 00:23:47,592 --> 00:23:49,392
# and so have their menus.
#
# 643
# 00:23:49,394 --> 00:23:50,634
# It's dead.
#
# 644
# 00:23:50,629 --> 00:23:52,799
# And Let There Be Bacon
# finally returned
#
# 645
# 00:23:52,798 --> 00:23:55,598
# from the store with the shrimp
# they desperately needed.
#
# 646
# 00:23:55,600 --> 00:23:56,800
# Thanks for
# waiting with us.
#
# 647
# 00:23:59,838 --> 00:24:01,338
# Hey, guys, it's Tyler.
#
# 648
# 00:24:01,339 --> 00:24:03,069
# Hey, Tyler.
# Hi, Tyler.
#
# 649
# 00:24:03,074 --> 00:24:05,284
# This is crazy!
# We've been waiting
# for your call.
#
# 650
# 00:24:05,277 --> 00:24:06,707
# <i>Wasn't there
# supposed to be</i>
#
# 651
# 00:24:06,711 --> 00:24:08,251
# <i>a brunch challenge today
# or something?</i>
#
# 652
# 00:24:08,246 --> 00:24:09,246
# Oh, brunch, yeah, yeah.
#
# 653
# 00:24:09,247 --> 00:24:10,447
# Brunch, brunch, brunch.
# Um...
#
# 654
# 00:24:10,448 --> 00:24:12,348
# <i>I've already tasted
# all your food.</i>
#
# 655
# 00:24:12,350 --> 00:24:13,690
# You already tasted it?
#
# 656
# 00:24:13,685 --> 00:24:14,685
# Oh, boy.
#
# 657
# 00:24:14,686 --> 00:24:16,116
# He already tasted
# our dishes.
#
# 658
# 00:24:16,121 --> 00:24:17,661
# <i>It wasn't me.</i>
#
# 659
# 00:24:17,656 --> 00:24:18,816
# But it was.
#
# 660
# 00:24:18,824 --> 00:24:20,464
# Oh, no.
# Okay.
#
# 661
# 00:24:20,458 --> 00:24:22,858
# I pulled private shoppers
# out of line
#
# 662
# 00:24:22,861 --> 00:24:24,501
# <i>to try the food because</i>
#
# 663
# 00:24:24,496 --> 00:24:26,196
# <i>I want to know what
# everybody else gets.</i>
#
# 664
# 00:24:26,198 --> 00:24:27,598
# I don't want any
# special treatment.
#
# 665
# 00:24:27,599 --> 00:24:29,399
# <i>I know,
# I'm sneaky.</i>
#
# 666
# 00:24:29,401 --> 00:24:32,571
# Now the big question is,
# who won the brunch challenge?
#
# 667
# 00:24:32,571 --> 00:24:35,711
# <i>Who is moving on to our
# $1,000 seafood challenge?</i>
#
# 668
# 00:24:35,707 --> 00:24:37,277
# Oh, please, God.
#
# 669
# 00:24:37,275 --> 00:24:38,535
# You guys ready to find out?
#
# 670
# 00:24:38,543 --> 00:24:41,013
# We are dying to know who won
# the cooking challenge.
#
# 671
# 00:24:41,012 --> 00:24:43,552
# <i>All right, remember,
# there's three teams left.</i>
#
# 672
# 00:24:43,548 --> 00:24:45,878
# The best two brunch dishes
#
# 673
# 00:24:45,884 --> 00:24:48,794
# <i>move on to our
# $1,000 seafood challenge.</i>
#
# 674
# 00:24:48,787 --> 00:24:51,157
# That is a lot of money
# in the till, and I promise you
#
# 675
# 00:24:51,156 --> 00:24:52,416
# <i>one of you are
# going to need it.</i>
#
# 676
# 00:24:52,424 --> 00:24:53,994
# The suspense is killing me,
# Tyler!
#
# 677
# 00:24:53,992 --> 00:24:55,532
# <i>All right, guys.</i>
#
# 678
# 00:24:55,527 --> 00:24:56,627
# <i>Pack it up</i>
#
# 679
# 00:24:56,628 --> 00:24:58,658
# and head down to
# the BraggâMitchell Mansion
#
# 680
# 00:24:58,663 --> 00:24:59,833
# on Springhill Road.
#
# 681
# 00:24:59,831 --> 00:25:01,531
# We're shutting down.
# So we still don't know?
#
# 682
# 00:25:01,533 --> 00:25:03,603
# <i>It's time for our cooking
# challenge here in Mobile.</i>
#
# 683
# 00:25:03,602 --> 00:25:04,772
# We won't find out
# until then?
#
# 684
# 00:25:04,769 --> 00:25:06,039
# Let's cook some seafood.
#
# 685
# 00:25:06,037 --> 00:25:08,937
# This brunch cookâoff
# already happened.
#
# 686
# 00:25:08,940 --> 00:25:12,510
# You are a sneaky,
# sneaky man, Tyler Florence.
#
# 687
# ...
#
# 927
# 00:33:43,020 --> 00:33:45,390
# It's awesome to have
# a chef of his talent
#
# 928
# 00:33:45,390 --> 00:33:46,890
# say that he loves our food.
#
# 929
# 00:33:46,891 --> 00:33:49,061
# We need this $1,000
# in our till.
#
# 930
# 00:33:49,060 --> 00:33:51,600
# I really think we have a good
# shot to win this competition.
#
# 931
# 00:33:51,596 --> 00:33:53,356
# All right, Lone Star.
#
# 932
# 00:33:53,364 --> 00:33:56,074
# This dish to me looks like
#
# 933
# 00:33:56,067 --> 00:33:58,797
# a dish that you'd walk in
# a restaurant and pay
#
# 934
# 00:33:58,803 --> 00:34:00,913
# 32 bucks for.
# Visually,
#
# 935
# 00:34:00,905 --> 00:34:02,135
# completely appealing,
#
# 936
# 00:34:02,140 --> 00:34:03,540
# highâend,
#
# 937
# 00:34:03,541 --> 00:34:05,041
# what I expect out of you.
#
# 938
# 00:34:05,042 --> 00:34:07,482
# Tell me where you think
# the flaws are in this dish.
#
# 939
# 00:34:07,478 --> 00:34:09,908
# I think the fish
# might be a little salty.
#
# 940
# 00:34:09,914 --> 00:34:11,484
# Other than that,
#
# 941
# 00:34:11,482 --> 00:34:14,422
# I stand behind
# everything in the dish.
#
# 942
# 00:34:14,419 --> 00:34:16,589
# When I put this piece
# of tilapia in my mouth,
#
# 943
# 00:34:16,587 --> 00:34:18,157
# the first bite
#
# 944
# 00:34:18,156 --> 00:34:21,086
# I really,
# really loved.
#
# 945
# 00:34:21,092 --> 00:34:22,762
# It's not overcooked,
# it's not hammered,
#
# 946
# 00:34:22,760 --> 00:34:24,600
# it's moist, cooked on one side,
# nice char,
#
# 947
# 00:34:24,595 --> 00:34:26,855
# and then the salt
# really began to build,
#
# 948
# 00:34:26,864 --> 00:34:29,034
# and it built
# and it built and it built.
#
# 949
# 00:34:29,033 --> 00:34:33,343
# And honestly, this is about all
# we could possibly get through
#
# 950
# 00:34:33,337 --> 00:34:35,037
# of the dish.
#
# 951
# 00:34:35,039 --> 00:34:36,709
# We always want big,
# bold flavors,
#
# 952
# 00:34:36,707 --> 00:34:38,507
# so I put a lot of
# seasoning on there.
#
# 953
# 00:34:38,509 --> 00:34:40,549
# It's my fault.
# I screwed up.
#
# 954
# 00:34:40,545 --> 00:34:42,605
# So, who won?
#
# 955
# 00:34:42,613 --> 00:34:43,783
# Well,
#
# 956
# 00:34:43,781 --> 00:34:45,921
# after our deliberation,
#
# 957
# 00:34:45,917 --> 00:34:48,247
# we've got to give it
# to the Bacon crew here.
#
# 958
# 00:34:48,252 --> 00:34:50,222
# Your dish, you know,
# edged them out.
#
# 959
# 00:34:50,221 --> 00:34:51,791
# Thank God
# Lone Star overseasoned
#
# 960
# 00:34:51,789 --> 00:34:53,759
# and overcooked
# their fish and shrimp.
#
# 961
# 00:34:53,758 --> 00:34:54,928
# Thank God.
#
# 962
# 00:34:54,926 --> 00:34:56,626
# All right, guys,
# congratulations.
#
# 963
# 00:34:56,627 --> 00:34:58,827
# Bacon, you've got $1,000
# extra in your till.
#
# 964
# 00:34:58,830 --> 00:35:00,830
# Thank you, chefs.
# It feels very good.
#
# 965
# 00:35:00,832 --> 00:35:03,272
# This is going to boil down
# to a very slim margin.
#
# 966
# 00:35:03,267 --> 00:35:05,967
# Everybody was
# killing it this weekend.
#
# 967
# 00:35:05,970 --> 00:35:07,340
# I'll see you guys tomorrow
# at elimination.
#
# 968
# 00:35:07,338 --> 00:35:09,608
# Congratulations.
# Good job, guys.
#
# 969
# 00:35:09,607 --> 00:35:11,437
# Tomorrow is elimination
#
# 970
# 00:35:11,442 --> 00:35:14,012
# and I'm not feeling
# good about this.
#
# 971
# 00:35:14,011 --> 00:35:17,751
# Let's hope that we sold more
# than Middle Feast.
#
# 972
# 00:35:17,748 --> 00:35:19,418
# We're probably going to go home
# this week for this.
#
# 973
# 00:35:19,417 --> 00:35:22,417
# We won.
# I mean, that's all it is, man.
#
# 974
# 00:35:22,420 --> 00:35:25,420
# I feel a lot better going into
# eliminations tomorrow now.
#
# 975
# 00:35:25,423 --> 00:35:25,963
# I feel a lot better going into
# eliminations tomorrow now.
#
# 976
# 00:35:25,957 --> 00:35:26,957
# Absolutely.
#
# 977
# 00:35:26,958 --> 00:35:29,158
# Tomorrow's going to
# be intense.
#
# 978
# 00:35:29,160 --> 00:35:31,560
# Let's get these doors closed up,
# let's get out of here.
#
# 979
# 00:35:41,839 --> 00:35:42,939
# So, teams, here we are.
#
# 980
# 00:35:42,940 --> 00:35:44,710
# Elimination number six.
#
# 981
# 00:35:44,709 --> 00:35:45,439
# We've lost Chatty Chicken,
#
# 982
# 00:35:45,443 --> 00:35:46,883
# We've lost Chatty Chicken,
#
# 983
# 00:35:46,878 --> 00:35:48,448
# the Gourmet Grads,
#
# 984
# 00:35:48,446 --> 00:35:49,706
# Madres Mexican Meals,
#
# 985
# 00:35:49,714 --> 00:35:51,784
# Military Moms,
# and Beach Cruiser.
#
# 986
# 00:35:51,782 --> 00:35:54,592
# We're about to find out
# which two teams
#
# 987
# 00:35:54,585 --> 00:35:56,545
# are headed to our finale.
#
# 988
# 00:35:56,554 --> 00:36:00,464
# Mobile was an incredible town
# for the Great Food Truck Race.
#
# 989
# 00:36:00,458 --> 00:36:05,198
# The three of you were $40 short
#
# 990
# 00:36:05,196 --> 00:36:07,896
# of $25,000 in sales
# this weekend.
#
# 991
# 00:36:07,899 --> 00:36:09,469
# Now, just to put that
#
# 992
# 00:36:09,467 --> 00:36:12,167
# in perspective,
# our first weekend in Venice,
#
# 993
# 00:36:12,169 --> 00:36:15,439
# California,
# we had $6,500 in sales,
#
# 994
# 00:36:15,439 --> 00:36:16,939
# and that was with eight trucks.
#
# 995
# 00:36:16,941 --> 00:36:19,611
# There is money
# to be made, guys.
#
# 996
# 00:36:19,610 --> 00:36:21,680
# So let's talk about Saturday
# speed bumps for a second.
#
# 997
# 00:36:21,679 --> 00:36:22,849
# Andrea, how was the challenge?
#
# 998
# 00:36:22,847 --> 00:36:25,217
# Still defrosting,
# but it was really fun
#
# 999
# 00:36:25,216 --> 00:36:27,516
# and it was worth it
# in the end, so...
#
# 1000
# 00:36:27,518 --> 00:36:29,748
# Was winning that much shrimp
# a blessing or a curse?
#
# 1001
# 00:36:29,754 --> 00:36:30,994
# A little bit of both.
#
# 1002
# 00:36:30,988 --> 00:36:32,588
# You know,
# it's fantastic to have
#
# 1003
# 00:36:32,590 --> 00:36:34,130
# 77 pounds of
# beautiful shrimp,
#
# 1004
# 00:36:34,125 --> 00:36:35,755
# but it takes
# a really long time
#
# 1005
# 00:36:35,760 --> 00:36:37,090
# to peel shrimp.
#
# 1006
# 00:36:37,094 --> 00:36:38,904
# So, Bacon, didn't we have
# a whole lesson
#
# 1007
# 00:36:38,896 --> 00:36:40,226
# dedicated to
# time management?
#
# 1008
# 00:36:40,231 --> 00:36:41,271
# Yes, sir.
#
# 1009
# 00:36:41,265 --> 00:36:43,065
# You guys took
# two hours to prep
#
# 1010
# 00:36:43,067 --> 00:36:44,367
# both Saturday and Sunday,
#
# 1011
# 00:36:44,368 --> 00:36:46,198
# so what was the slowest thing
# you had to prep?
#
# 1012
# 00:36:46,203 --> 00:36:47,873
# Shrimp.
# The shrimp, right?
#
# 1013
# 00:36:47,872 --> 00:36:48,972
# No question.
#
# 1014
# 00:36:48,973 --> 00:36:50,313
# Tommy, let's talk
# about you guys.
#
# 1015
# 00:36:50,308 --> 00:36:53,478
# So last week you guys
# were in the bottom two
#
# 1016
# 00:36:53,477 --> 00:36:56,077
# and almost went home
# for $160.
#
# 1017
# 00:36:56,080 --> 00:36:59,820
# That just boils down to 20
# or 30 minutes' worth of sales.
#
# 1018
# 00:36:59,817 --> 00:37:01,447
# You taking a long time
# to get prepped,
#
# 1019
# 00:37:01,452 --> 00:37:03,892
# was it worth the mint or
# the parsley or the fresh kale?
#
# 1020
# 00:37:03,888 --> 00:37:05,718
# Yes. Yes.
# It was. Okay.
#
# 1021
# 00:37:05,723 --> 00:37:06,823
# So, Lone Star,
#
# 1022
# 00:37:06,824 --> 00:37:08,764
# tell me what happened
# Sunday at the store.
#
# 1023
# 00:37:08,759 --> 00:37:10,459
# I heard you guys
# bought some grouper
#
# 1024
# 00:37:10,461 --> 00:37:12,531
# but it never ended up
# on the menu.
#
# 1025
# 00:37:12,530 --> 00:37:13,760
# What happened to that?
#
# 1026
# 00:37:13,764 --> 00:37:15,234
# We ordered the grouper,
# and as he was
#
# 1027
# 00:37:15,232 --> 00:37:16,832
# bagging it up,
# we asked about the sausage,
#
# 1028
# 00:37:16,834 --> 00:37:18,244
# so they were
# showing us the sausage,
#
# 1029
# 00:37:18,236 --> 00:37:19,596
# we were excited
# about the sausage.
#
# 1030
# 00:37:19,604 --> 00:37:22,044
# So you left it on
# the counter by mistake.
#
# 1031
# 00:37:22,039 --> 00:37:24,379
# Right.
# That was a genuine
# mistake on your part.
#
# 1032
# 00:37:24,375 --> 00:37:25,435
# Yes.
#
# 1033
# 00:37:25,443 --> 00:37:27,253
# You guys leaving that
# grouper on the counter
#
# 1034
# 00:37:27,245 --> 00:37:29,045
# could have made the difference
# in you winning
#
# 1035
# 00:37:29,046 --> 00:37:30,546
# that cooking
# competition yesterday.
#
# 1036
# 00:37:30,548 --> 00:37:32,848
# Yeah.
# It's the little mistakes.
#
# 1037
# 00:37:32,850 --> 00:37:34,890
# So, guys, it's time
# to get down to business.
#
# 1038
# 00:37:34,885 --> 00:37:37,045
# It's time to find out
# who made the most,
#
# 1039
# 00:37:37,054 --> 00:37:38,594
# who made the least,
#
# 1040
# 00:37:38,589 --> 00:37:39,959
# who won the city,
#
# 1041
# 00:37:39,957 --> 00:37:42,157
# and who will be
# handing in their keys
#
# 1042
# 00:37:42,159 --> 00:37:44,399
# and heading home.
#
# 1043
# 00:37:44,395 --> 00:37:45,525
# In first place,
#
# 1044
# 00:37:45,529 --> 00:37:48,069
# with $10,058,
#
# 1045
# 00:37:48,065 --> 00:37:51,565
# unprecedented.
#
# 1046
# 00:37:51,569 --> 00:37:54,639
# Middle Feast.
# Congratulations, guys.
#
# 1047
# 00:37:54,639 --> 00:37:55,739
# Nice job.
#
# 1048
# 00:37:55,740 --> 00:37:57,980
# So unbelievable.
#
# 1049
# 00:37:57,975 --> 00:38:00,975
# Three crazy Israelis
# in the finals.
#
# 1050
# 00:38:00,978 --> 00:38:02,348
# That's awesome.
#
# 1051
# 00:38:02,346 --> 00:38:04,116
# Guys, you are one step closer
#
# 1052
# 00:38:04,115 --> 00:38:06,575
# to winning a prize worth
# about $150,000.
#
# 1053
# 00:38:06,584 --> 00:38:12,294
# Last week we almost
# went home for $160's difference,
#
# 1054
# 00:38:12,290 --> 00:38:14,660
# and right now,
# we're first place.
#
# 1055
# 00:38:14,659 --> 00:38:16,559
# This is the best feeling ever.
#
# 1056
# 00:38:19,030 --> 00:38:20,530
# Being in the bottom two
#
# 1057
# 00:38:20,531 --> 00:38:22,501
# is where we were in the
# beginning of this competition.
#
# 1058
# 00:38:22,500 --> 00:38:24,840
# We were hoping to never
# be here again,
#
# 1059
# 00:38:24,835 --> 00:38:26,865
# but you get down
# to three teams,
#
# 1060
# 00:38:26,871 --> 00:38:28,141
# good teams good home.
#
# 1061
# 00:38:28,139 --> 00:38:30,339
# That leaves
# Let There Be Bacon
#
# 1062
# 00:38:30,341 --> 00:38:32,141
# and the Lone Star Chuck Wagon,
# two teams that I've
#
# 1063
# 00:38:32,143 --> 00:38:34,383
# really enjoyed
# following this race.
#
# 1064
# 00:38:34,378 --> 00:38:36,308
# One of you is
# moving on to the finale
#
# 1065
# 00:38:36,314 --> 00:38:38,654
# and one of you
# is about to go home.
#
# 1066
# 00:38:38,649 --> 00:38:41,119
# Lance, if you go home
# this weekend, tell me why.
#
# 1067
# 00:38:41,118 --> 00:38:42,718
# Well, the first thing
# that comes to mind
#
# 1068
# 00:38:42,720 --> 00:38:43,820
# is overâsalting my fish.
#
# 1069
# 00:38:43,821 --> 00:38:45,561
# I hate being
# in the bottom two.
#
# 1070
# 00:38:45,556 --> 00:38:46,916
# It's the worst feeling.
#
# 1071
# 00:38:46,924 --> 00:38:49,864
# Every time we're here,
# I am kicking myself
#
# 1072
# 00:38:49,860 --> 00:38:52,460
# because it's always
# a silly mistake.
#
# 1073
# 00:38:52,463 --> 00:38:54,473
# Bacon, what was
# your flaw this weekend?
#
# 1074
# 00:38:54,465 --> 00:38:55,595
# Time management
#
# 1075
# 00:38:55,599 --> 00:38:57,769
# and probably
# buying more shrimp
#
# 1076
# 00:38:57,768 --> 00:38:59,498
# just slowed us down
# with our prep time.
#
# 1077
# 00:38:59,503 --> 00:39:02,443
# All right,
# here we go, guys.
#
# 1078
# 00:39:02,440 --> 00:39:04,410
# In third place
# and going home...
#
# 1079
# 00:39:07,378 --> 00:39:08,948
# With a difference
#
# 1080
# 00:39:08,946 --> 00:39:10,306
# of $582...
#
# 1081
# 00:39:12,783 --> 00:39:15,793
# Let There Be Bacon.
# I'm sorry, guys.
#
# 1082
# 00:39:20,891 --> 00:39:23,131
# Holy crap,
# we get a second chance.
#
# 1083
# 00:39:23,127 --> 00:39:24,797
# We get to go to the finale.
#
# 1084
# 00:39:24,795 --> 00:39:26,055
# This feels so good.
#
# 1085
# 00:39:26,063 --> 00:39:28,573
# We deserve this,
# we've worked so hard.
#
# 1086
# 00:39:28,566 --> 00:39:29,866
# So, Lone Star Chuck Wagon,
#
# 1087
# 00:39:29,867 --> 00:39:32,167
# that means you have
# made it to our finale.
#
# 1088
# 00:39:32,169 --> 00:39:33,169
# Congratulations,
#
# 1089
# 00:39:33,170 --> 00:39:36,070
# and you are safe,
# please step back.
#
# 1090
# 00:39:36,073 --> 00:39:37,583
# Guys, you had a grand total
#
# 1091
# 00:39:37,575 --> 00:39:40,135
# of $7,160,
#
# 1092
# 00:39:40,144 --> 00:39:46,254
# just $582 shy
# of making the finale.
#
# 1093
# 00:39:46,250 --> 00:39:48,450
# I'm really disappointed
# that we're going home,
#
# 1094
# 00:39:48,452 --> 00:39:50,522
# but after this weekend,
# I'm not surprised.
#
# 1095
# 00:39:50,521 --> 00:39:51,861
# We made way too many mistakes
#
# 1096
# 00:39:51,856 --> 00:39:53,756
# and we did not have
# our focus together.
#
# 1097
# 00:39:56,861 --> 00:39:58,831
# Keep that
# head up, buddy.
#
# 1098
# 00:39:58,829 --> 00:40:02,829
# Head's up.
# Heart hurts.
#
# 1099
# 00:40:02,833 --> 00:40:04,003
# Listen, before you guys go,
#
# 1100
# 00:40:04,001 --> 00:40:05,041
# I've got a lot I want to say.
#
# 1101
# 00:40:05,035 --> 00:40:06,335
# You guys latched on the idea
#
# 1102
# 00:40:06,337 --> 00:40:08,737
# of marketing like nobody else
# in this competition.
#
# 1103
# 00:40:08,739 --> 00:40:11,409
# You guys took your bacon brand
# and you literally created
#
# 1104
# 00:40:11,408 --> 00:40:13,008
# a bacon army.
#
# 1105
# 00:40:13,010 --> 00:40:14,580
# I've never seen a more loyal,
#
# 1106
# 00:40:14,578 --> 00:40:16,748
# more resilient bunch in
# the five years
#
# 1107
# 00:40:16,747 --> 00:40:18,217
# that we've been
# doing this race.
#
# 1108
# 00:40:18,215 --> 00:40:20,415
# I want you guys to take all
# these lessons back to Cleveland
#
# 1109
# 00:40:20,417 --> 00:40:21,587
# and bring the bacon
# to the people.
#
# 1110
# 00:40:21,585 --> 00:40:23,345
# Oh, absolutely.
#
# 1111
# 00:40:23,354 --> 00:40:25,594
# And, Matt, here's my
# last word for you.
#
# 1112
# 00:40:25,589 --> 00:40:27,659
# The Bacon Army,
# they need a leader,
#
# 1113
# 00:40:27,658 --> 00:40:28,828
# and you're that guy.
#
# 1114
# 00:40:28,826 --> 00:40:32,226
# That's a lot of pressure, Chef.
#
# 1115
# 00:40:32,229 --> 00:40:34,199
# Guys, I'm really sorry,
# but I need your keys.
#
# 1116
# 00:40:34,198 --> 00:40:36,768
# Thank you so much.
#
# 1117
# 00:40:36,767 --> 00:40:39,537
# Give me a hug, man.
#
# 1118
# 00:40:39,537 --> 00:40:41,707
# All right, Bacon Army.
# Just hold on.
#
# 1119
# 00:40:41,705 --> 00:40:43,635
# We're coming back.
#
# 1120
# 00:40:43,641 --> 00:40:45,611
# Be ready for that
# call to action when it comes.
#
# 1121
# 00:40:45,609 --> 00:40:48,549
# This is just the
# beginning of Let There Be Bacon.
#
# 1122
# 00:40:48,546 --> 00:40:50,976
# It's a hell
# of a first chapter.
#
# 1123
# 00:40:50,981 --> 00:40:53,781
# Well, the name is
# Let There Be Bacon.
#
# 1124
# 00:40:53,784 --> 00:40:55,624
# It's not There Was Bacon.
#
# 1125
# 00:40:55,619 --> 00:40:59,189
# Well, guys,
# now we have two teams left,
#
# 1126
# 00:40:59,190 --> 00:41:02,330
# two teams that have been through
# an amazing journey
#
# 1127
# 00:41:02,326 --> 00:41:03,556
# and have survived.
#
# 1128
# 00:41:03,561 --> 00:41:05,801
# Now, who's ready to
# find out our next city?
#
# 1129
# 00:41:05,796 --> 00:41:06,826
# Yeah. Yeah.
#
# 1130
# 00:41:06,831 --> 00:41:09,401
# We are going to leave Mobile,
# Alabama,
#
# 1131
# 00:41:09,400 --> 00:41:11,800
# in our rearview mirror,
# and you have
#
# 1132
# 00:41:11,802 --> 00:41:14,002
# a 500âmile journey
# ahead of you.
#
# 1133
# 00:41:14,004 --> 00:41:16,314
# We are looping it
# around the gulf,
#
# 1134
# 00:41:16,307 --> 00:41:18,507
# heading south to Tampa,
# Florida.
#
# 1135
# 00:41:18,509 --> 00:41:20,949
# Tampa's a great town,
# but let me tell you,
#
# 1136
# 00:41:20,945 --> 00:41:23,875
# Tampa Bay is just
# our jumpingâoff point.
#
# 1137
# 00:41:23,881 --> 00:41:27,621
# This finale will be epic
# and brutal on everybody.
#
# 1138
# 00:41:27,618 --> 00:41:29,218
# Is everybody ready
#
# 1139
# 00:41:29,220 --> 00:41:30,690
# to head to
# the Sunshine State?
#
# 1140
# 00:41:30,688 --> 00:41:31,918
# Yeah.
# Yes.
#
# 1141
# 00:41:31,922 --> 00:41:33,592
# I'll see you in Florida.
# Let's get rolling!
#
# 1142
# 00:41:44,802 --> 00:41:47,072
# Next time on
# "The Great Food Truck Race"...
#
# 1143
# 00:41:47,071 --> 00:41:48,871
# You are standing
# at the starting line
#
# 1144
# 00:41:48,873 --> 00:41:51,483
# of an epic finale that
# will cover five cities
#
# 1145
# 00:41:51,475 --> 00:41:53,675
# and over 450 miles.
#
# 1146
# 00:41:53,677 --> 00:41:54,677
# Into the finale.
#
# 1147
# 00:41:54,678 --> 00:41:56,078
# Are you
# ready for war?
#
# 1148
# 00:41:56,080 --> 00:41:58,320
# I'm going to meet you
# at Alligator Alley.
#
# 1149
# 00:41:58,315 --> 00:42:00,075
# Wow.
#
# 1150
# 00:42:00,084 --> 00:42:01,724
# Alligator and frog legs.
#
# 1151
# 00:42:01,719 --> 00:42:03,149
# Oh, boy!
#
# 1152
# 00:42:03,153 --> 00:42:04,823
# Let's push it hard.
#
# 1153
# 00:42:04,822 --> 00:42:07,492
# We are driving to
# the end of the earth.
#
# 1154
# 00:42:07,491 --> 00:42:08,791
# This race is over,
# we are 100% done.
#
# 1155
# 00:42:08,792 --> 00:42:11,962
# And the winner of "The Great
# Food Truck Race" is...
#
# 1156
# 00:42:13,530 --> 00:42:16,000
# Closed Captions provided by
# Scripps Networks, LLC.
#
# 1156
# 00:42:17,305 --> 00:43:17,415
# Please rate this subtitle at www.osdb.link/ah4ag
# Help other users to choose the best subtitles

# %% [markdown]
# ## **Step 6 - Applying the above Function on the Entire Data**

# %%
count = 0

def decode_method(binary_data):
    global count
    # Decompress the binary data using the zipfile module
    # print(count, end=" ")
    count += 1
    with io.BytesIO(binary_data) as f:
        with zipfile.ZipFile(f, 'r') as zip_file:
            # Assuming there's only one file in the ZIP archive
            subtitle_content = zip_file.read(zip_file.namelist()[0])
    
    # Now 'subtitle_content' should contain the extracted subtitle content
    return subtitle_content.decode('latin-1')  # Assuming the content is UTF-8 encoded text

# %%
df['file_content'] = df['content'].apply(decode_method)

df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...

# %%
len(df)
# Out:
# 82498

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82498 entries, 0 to 82497
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num           82498 non-null  int64
#  1   name          82498 non-null  object
#  2   content       82498 non-null  object
#  3   file_content  82498 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.5+ MB

# %%
df.tail()
# Out:
#            num                                        name  \
# 82493  9521935            the.prophets.game.(2000).eng.1cd
# 82494  9521937                  west.beirut.(1998).eng.1cd
# 82495  9521938  frankenstein.the.true.story.(1973).eng.1cd
# 82496  9521940  frankenstein.the.true.story.(1973).eng.1cd
# 82497  9521941       zombie.island.massacre.(1984).eng.1cd
#
#                                                  content  \
# 82493  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xb8\xa6\x...
# 82494  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x13\x97\x...
# 82495  b'PK\x03\x04\x14\x00\x00\x00\x08\x00$\x97\x9aV...
# 82496  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x00\x97\x...
# 82497  b'PK\x03\x04\x14\x00\x00\x00\x08\x00,\x97\x9aV...
#
#                                             file_content
# 82493  ï»¿1\r\n00:01:16,284 --> 00:01:19,537\r\nGod,\...
# 82494  1\r\n00:00:06,000 --> 00:00:12,074\r\napi.Open...
# 82495  1\r\n00:00:01,001 --> 00:00:04,630\r\n(Dramati...
# 82496  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 82497  1\r\n00:00:01,919 --> 00:00:03,253\r\n(Sharp w...

# %% [markdown]
# ### DROPPING THE "CONTENT" COLUMN

# %%
df =  df.drop(columns='content')

# %%
df.tail()
# Out:
#            num                                        name  \
# 82493  9521935            the.prophets.game.(2000).eng.1cd
# 82494  9521937                  west.beirut.(1998).eng.1cd
# 82495  9521938  frankenstein.the.true.story.(1973).eng.1cd
# 82496  9521940  frankenstein.the.true.story.(1973).eng.1cd
# 82497  9521941       zombie.island.massacre.(1984).eng.1cd
#
#                                             file_content
# 82493  ï»¿1\r\n00:01:16,284 --> 00:01:19,537\r\nGod,\...
# 82494  1\r\n00:00:06,000 --> 00:00:12,074\r\napi.Open...
# 82495  1\r\n00:00:01,001 --> 00:00:04,630\r\n(Dramati...
# 82496  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 82497  1\r\n00:00:01,919 --> 00:00:03,253\r\n(Sharp w...

# %% [markdown]
# ### RENAMING THE COLUMN NAMES

# %%
df.rename(columns={"num":"id",
             "name":"Movies/Series",
             "file_content":"subtitles"},inplace=True)

# %%
df.head()
# Out:
#         id                                      Movies/Series  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                            subtitles
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...

# %% [markdown]
# ### RANDOMLY TAKING 10% DATA

# %%
total_rows=len(df)
percent_data=int(total_rows* 0.10)
df_10_percent_data=df.iloc[:percent_data]

# %%
len(df_10_percent_data)
# Out:
# 8249

# %% [markdown]
# #  Preprocessing of data

# %%
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# C:\Users\deshp\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# **`removing special characters`**

# %%
df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'[^a-zA-Z\s]', '')
# Out:
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\3737590331.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'[^a-zA-Z\s]', '')
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\3737590331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'[^a-zA-Z\s]', '')

# %% [markdown]
# **`removing non ASCII characters`**

# %%
df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'[^\x00-\x7F]+', '')
# Out:
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\2534907674.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'[^\x00-\x7F]+', '')
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\2534907674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'[^\x00-\x7F]+', '')

# %% [markdown]
# **`removing time-stamp`**

# %%
df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'\d{2}:\d{2}:\d{2}\d{3} --> \d{2}:\d{2}:\d{2},\d{3}', '')
# Out:
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\3057987915.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'\d{2}:\d{2}:\d{2}\d{3} --> \d{2}:\d{2}:\d{2},\d{3}', '')
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\3057987915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'\d{2}:\d{2}:\d{2}\d{3} --> \d{2}:\d{2}:\d{2},\d{3}', '')

# %% [markdown]
# **`converting to lowercase`**

# %%
df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.lower()
# Out:
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\1994596723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.lower()

# %% [markdown]
# **`removing extra spaces`**

# %%
df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'\s+', ' ' )
# Out:
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\1886929374.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'\s+', ' ' )
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\1886929374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].str.replace(r'\s+', ' ' )

# %%
df_10_percent_data['subtitles']
# Out:
# 0        watch any video online with opensubtitles fre...
# 1        ah theres princess dawn and terry with the bl...
# 2        iyumis cells i iepisode extremely polite yumi...
# 3        watch any video online with opensubtitles fre...
# 4        watch any video online with opensubtitles fre...
#                               ...
# 8244     apiopensubtitlesorg is deprecated please impl...
# 8245     advertise your product or brand here contact ...
# 8246     watch any video online with opensubtitles fre...
# 8247    script info title english us original script k...
# 8248     support us and become vip member to remove al...
# Name: subtitles, Length: 8249, dtype: object

# %%
# !pip install swifter
# Out:
# Requirement already satisfied: swifter in c:\users\deshp\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\deshp\anaconda3\lib\site-packages (from swifter) (5.8.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\deshp\anaconda3\lib\site-packages (from swifter) (1.4.2)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\deshp\anaconda3\lib\site-packages (from swifter) (4.66.2)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\deshp\anaconda3\lib\site-packages (from swifter) (2022.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\deshp\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\deshp\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\deshp\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\deshp\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2024.3.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\deshp\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2.0.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\deshp\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\deshp\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.26.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\deshp\anaconda3\lib\site-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deshp\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\deshp\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: locket in c:\users\deshp\anaconda3\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (0.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\deshp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->swifter) (1.16.0)
# Requirement already satisfied: colorama in c:\users\deshp\anaconda3\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.4)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)

# %%
import swifter

# %% [markdown]
# **`Tokenization step`**

# %%
df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].swifter.apply(lambda x: word_tokenize(x))
# Out:
# Pandas Apply:   0%|          | 0/8249 [00:00<?, ?it/s]
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\2061605895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['subtitles'] = df_10_percent_data['subtitles'].swifter.apply(lambda x: word_tokenize(x))

# %%
df_10_percent_data['subtitles']
# Out:
# 0       [watch, any, video, online, with, opensubtitle...
# 1       [ah, theres, princess, dawn, and, terry, with,...
# 2       [iyumis, cells, i, iepisode, extremely, polite...
# 3       [watch, any, video, online, with, opensubtitle...
# 4       [watch, any, video, online, with, opensubtitle...
#                               ...
# 8244    [apiopensubtitlesorg, is, deprecated, please, ...
# 8245    [advertise, your, product, or, brand, here, co...
# 8246    [watch, any, video, online, with, opensubtitle...
# 8247    [script, info, title, english, us, original, s...
# 8248    [support, us, and, become, vip, member, to, re...
# Name: subtitles, Length: 8249, dtype: object

# %%
df_10_percent_data
# Out:
#            id                                      Movies/Series  \
# 0     9180533                         the.message.(1976).eng.1cd
# 1     9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2     9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3     9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4     9180600                              broker.(2022).eng.1cd
# ...       ...                                                ...
# 8244  9215813                      gossamer.folds.(2020).eng.1cd
# 8245  9215815                      gossamer.folds.(2020).eng.1cd
# 8246  9215856                 the.app.from.heaven.(2017).eng.1cd
# 8247  9215897    orient.s02.e07.a.matter.of.trust.(2022).eng.1cd
# 8248  9215903                spitfire.over.berlin.(2022).eng.1cd
#
#                                               subtitles
# 0     [watch, any, video, online, with, opensubtitle...
# 1     [ah, theres, princess, dawn, and, terry, with,...
# 2     [iyumis, cells, i, iepisode, extremely, polite...
# 3     [watch, any, video, online, with, opensubtitle...
# 4     [watch, any, video, online, with, opensubtitle...
# ...                                                 ...
# 8244  [apiopensubtitlesorg, is, deprecated, please, ...
# 8245  [advertise, your, product, or, brand, here, co...
# 8246  [watch, any, video, online, with, opensubtitle...
# 8247  [script, info, title, english, us, original, s...
# 8248  [support, us, and, become, vip, member, to, re...
#
# [8249 rows x 3 columns]

# %%
df_10_percent_data.head()
# Out:
#         id                                      Movies/Series  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                            subtitles
# 0  [watch, any, video, online, with, opensubtitle...
# 1  [ah, theres, princess, dawn, and, terry, with,...
# 2  [iyumis, cells, i, iepisode, extremely, polite...
# 3  [watch, any, video, online, with, opensubtitle...
# 4  [watch, any, video, online, with, opensubtitle...

# %%
len(df_10_percent_data)
# Out:
# 8249

# %% [markdown]
# ## TFIDF-approach

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df_10_percent_data['subtitles'])

# Sparse matrix representation of TF-IDF
print(tfidf_matrix)
# Out:
#   (0, 226502)	0.001525948224892838
#   (0, 245915)	0.0015495171655121648
#   (0, 256404)	0.008243210796051071
#   (0, 226062)	0.0015317260714399195
#   (0, 197080)	0.001470572380728476
#   (0, 128507)	0.008243210796051071
#   (0, 229341)	0.006523011873745068
#   (0, 42799)	0.0026871656045789373
#   (0, 107898)	0.004918282155982931
#   (0, 190873)	0.006588523867654451
#   (0, 244444)	0.0025353788036615757
#   (0, 103895)	0.005390885775324752
#   (0, 253216)	0.005397700828561956
#   (0, 187202)	0.005738629305752286
#   (0, 157289)	0.006351376525133158
#   (0, 121602)	0.004456488685117844
#   (0, 167449)	0.008243210796051071
#   (0, 72669)	0.004386199435110583
#   (0, 111000)	0.0024583444650589027
#   (0, 190889)	0.005738629305752286
#   (0, 255791)	0.012329155455972197
#   (0, 166129)	0.0078847766502921
#   (0, 63949)	0.004167797366322736
#   (0, 110377)	0.002979352468366305
#   (0, 77027)	0.005179474699146711
#   :	:
#   (8248, 252788)	0.010523406498066037
#   (8248, 234524)	0.04100554006128041
#   (8248, 138785)	0.010380190702557966
#   (8248, 121971)	0.07489231804066729
#   (8248, 250433)	0.005190724641927043
#   (8248, 171440)	0.006070820083749669
#   (8248, 96932)	0.010552805593372242
#   (8248, 261176)	0.030911131956647204
#   (8248, 83444)	0.049031703517233585
#   (8248, 5520)	0.005633658383361672
#   (8248, 97155)	0.028387317064532954
#   (8248, 260715)	0.29294466175524597
#   (8248, 119893)	0.05140626182233894
#   (8248, 253324)	0.0026487840224594175
#   (8248, 99706)	0.008076644550815358
#   (8248, 236687)	0.13757414204488985
#   (8248, 85380)	0.012873394535738051
#   (8248, 166153)	0.0034827192798399095
#   (8248, 90143)	0.0033416685605792834
#   (8248, 177112)	0.03598002147805119
#   (8248, 233215)	0.17349368525531347
#   (8248, 114242)	0.0745481159032097
#   (8248, 254662)	0.025696900153968947
#   (8248, 9971)	0.010785872346427037
#   (8248, 250667)	0.0034062298472507736

# %% [markdown]
# ### BERT based “SentenceTransformers” to generate embeddings which encode semantic information.
# ### This can help us build a Semantic Search Engine.

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\deshp\anaconda3\lib\site-packages (2.6.1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\deshp\\anaconda3\\Lib\\site-packages\\~2mpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: scikit-learn in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (0.21.4)
# Requirement already satisfied: scipy in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (2.2.1)
# Requirement already satisfied: tqdm in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: numpy in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\deshp\anaconda3\lib\site-packages (from sentence-transformers) (9.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\deshp\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.3.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\deshp\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (21.3)
# Requirement already satisfied: filelock in c:\users\deshp\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.6.0)
# Requirement already satisfied: requests in c:\users\deshp\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\deshp\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\deshp\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\deshp\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.15.1->sentence-transformers) (3.0.4)
# Requirement already satisfied: sympy in c:\users\deshp\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\deshp\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: networkx in c:\users\deshp\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.7.1)
# Requirement already satisfied: colorama in c:\users\deshp\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\deshp\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2022.3.15)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\deshp\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\deshp\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deshp\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deshp\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deshp\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deshp\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deshp\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\deshp\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\deshp\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.0)
# Collecting numpy
#   Using cached numpy-1.22.4-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\deshp\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.2.1)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4

# %%
from sentence_transformers import SentenceTransformer

# Load a pre-trained BERT model
name_of_model='multi-qa-MiniLM-L6-cos-v1'
model = SentenceTransformer(name_of_model)
text=df_10_percent_data['subtitles']
# Function to encode text using BERT
def encode_text(text):
    # Encode the text into an embedding
    embedding = model.encode(text)
    return embedding

# %%
# Apply BERT vectorization to the 'file_content' column



df_10_percent_data['bert_embedding'] = df_10_percent_data['subtitles'].apply(encode_text)
# Out:
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\3354575356.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['bert_embedding'] = df_10_percent_data['subtitles'].apply(encode_text)

# %%
df_10_percent_data['bert_embedding']
# Out:
# 0       [0.0429545, 0.047213517, -0.048022557, -0.0589...
# 1       [-0.017032498, 0.0084469365, 0.07423645, -0.01...
# 2       [-0.04869099, -0.04203135, 0.06548537, 0.03954...
# 3       [-0.043026306, -0.03555924, 0.059036024, -0.04...
# 4       [-0.024402311, 0.013387982, 0.123676725, -0.02...
#                               ...
# 8244    [0.077503555, -0.041504238, 0.03078112, -0.035...
# 8245    [0.033693567, -0.08421364, 0.07477469, -0.0781...
# 8246    [-0.06501349, 0.013136341, 0.05656268, -0.0415...
# 8247    [0.005435122, -0.025132079, 0.015010854, -0.03...
# 8248    [-0.020894008, 0.02490764, 0.028566448, -0.082...
# Name: bert_embedding, Length: 8249, dtype: object

# %%
df_10_percent_data
# Out:
#            id                                      Movies/Series  \
# 0     9180533                         the.message.(1976).eng.1cd
# 1     9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2     9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3     9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4     9180600                              broker.(2022).eng.1cd
# ...       ...                                                ...
# 8244  9215813                      gossamer.folds.(2020).eng.1cd
# 8245  9215815                      gossamer.folds.(2020).eng.1cd
# 8246  9215856                 the.app.from.heaven.(2017).eng.1cd
# 8247  9215897    orient.s02.e07.a.matter.of.trust.(2022).eng.1cd
# 8248  9215903                spitfire.over.berlin.(2022).eng.1cd
#
#                                               subtitles  \
# 0     watch any video online with opensubtitles free...
# 1     ah theres princess dawn and terry with the blo...
# 2     iyumis cells i iepisode extremely polite yumii...
# 3     watch any video online with opensubtitles free...
# 4     watch any video online with opensubtitles free...
# ...                                                 ...
# 8244  apiopensubtitlesorg is deprecated please imple...
# 8245  advertise your product or brand here contact w...
# 8246  watch any video online with opensubtitles free...
# 8247  script info title english us original script k...
# 8248  support us and become vip member to remove all...
#
#                                          bert_embedding
# 0     [0.0429545, 0.047213517, -0.048022557, -0.0589...
# 1     [-0.017032498, 0.0084469365, 0.07423645, -0.01...
# 2     [-0.04869099, -0.04203135, 0.06548537, 0.03954...
# 3     [-0.043026306, -0.03555924, 0.059036024, -0.04...
# 4     [-0.024402311, 0.013387982, 0.123676725, -0.02...
# ...                                                 ...
# 8244  [0.077503555, -0.041504238, 0.03078112, -0.035...
# 8245  [0.033693567, -0.08421364, 0.07477469, -0.0781...
# 8246  [-0.06501349, 0.013136341, 0.05656268, -0.0415...
# 8247  [0.005435122, -0.025132079, 0.015010854, -0.03...
# 8248  [-0.020894008, 0.02490764, 0.028566448, -0.082...
#
# [8249 rows x 4 columns]

# %%
df_10_percent_data['bert_embedding'].to_numpy()
subtitle_embeddings = df_10_percent_data['bert_embedding'].to_numpy()
np.save('subtitle_embeddings.npy', subtitle_embeddings)

# %%
#import json

# Function to convert numpy array to string
#def array_to_string(arr):
   # return json.dumps(arr.tolist())

# Apply the function to convert numpy arrays to strings
#df_10_percent_data['bert_embedding_str'] = df_10_percent_data['bert_embedding'].apply(array_to_string)

# %% [markdown]
# ### DOCUMNET CHUNKER

# %%
# Creating  a function that takes a large document as input and divides it into smaller chunks 
# with an overlap to maintain context continuity.

# %%
def semantic_chunking(embeddings, chunk_size=1000, overlap=50):
    chunks = []
    if isinstance(embeddings, np.ndarray) and len(embeddings.shape) == 1:
        # Single embedding (numpy array or float)
        embeddings = [embeddings]  # Convert to a list for consistency
    for embedding in embeddings:
        if isinstance(embedding, np.ndarray):
            embedding = ' '.join(map(str, embedding))  # Convert array to string
        else:
            embedding = str(embedding)  # Convert float to string
        for start in range(0, len(embedding), chunk_size - overlap):
            chunk = embedding[start:start + chunk_size]
            chunks.append(chunk)
    return chunks

# %%
df_10_percent_data['bert_embedding_chunks'] = df_10_percent_data['bert_embedding'].apply(semantic_chunking)
# Out:
# C:\Users\deshp\AppData\Local\Temp\ipykernel_6084\2294253286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10_percent_data['bert_embedding_chunks'] = df_10_percent_data['bert_embedding'].apply(semantic_chunking)

# %%
df_10_percent_data
# Out:
#            id                                      Movies/Series  \
# 0     9180533                         the.message.(1976).eng.1cd
# 1     9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2     9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3     9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4     9180600                              broker.(2022).eng.1cd
# ...       ...                                                ...
# 8244  9215813                      gossamer.folds.(2020).eng.1cd
# 8245  9215815                      gossamer.folds.(2020).eng.1cd
# 8246  9215856                 the.app.from.heaven.(2017).eng.1cd
# 8247  9215897    orient.s02.e07.a.matter.of.trust.(2022).eng.1cd
# 8248  9215903                spitfire.over.berlin.(2022).eng.1cd
#
#                                               subtitles  \
# 0     watch any video online with opensubtitles free...
# 1     ah theres princess dawn and terry with the blo...
# 2     iyumis cells i iepisode extremely polite yumii...
# 3     watch any video online with opensubtitles free...
# 4     watch any video online with opensubtitles free...
# ...                                                 ...
# 8244  apiopensubtitlesorg is deprecated please imple...
# 8245  advertise your product or brand here contact w...
# 8246  watch any video online with opensubtitles free...
# 8247  script info title english us original script k...
# 8248  support us and become vip member to remove all...
#
#                                          bert_embedding  \
# 0     [0.0429545, 0.047213517, -0.048022557, -0.0589...
# 1     [-0.017032498, 0.0084469365, 0.07423645, -0.01...
# 2     [-0.04869099, -0.04203135, 0.06548537, 0.03954...
# 3     [-0.043026306, -0.03555924, 0.059036024, -0.04...
# 4     [-0.024402311, 0.013387982, 0.123676725, -0.02...
# ...                                                 ...
# 8244  [0.077503555, -0.041504238, 0.03078112, -0.035...
# 8245  [0.033693567, -0.08421364, 0.07477469, -0.0781...
# 8246  [-0.06501349, 0.013136341, 0.05656268, -0.0415...
# 8247  [0.005435122, -0.025132079, 0.015010854, -0.03...
# 8248  [-0.020894008, 0.02490764, 0.028566448, -0.082...
#
#                                   bert_embedding_chunks
# 0     [0.0429545 0.047213517 -0.048022557 -0.0589091...
# 1     [-0.017032498 0.0084469365 0.07423645 -0.01032...
# 2     [-0.04869099 -0.04203135 0.06548537 0.03954125...
# 3     [-0.043026306 -0.03555924 0.059036024 -0.04153...
# 4     [-0.024402311 0.013387982 0.123676725 -0.02826...
# ...                                                 ...
# 8244  [0.077503555 -0.041504238 0.03078112 -0.035498...
# 8245  [0.033693567 -0.08421364 0.07477469 -0.0781623...
# 8246  [-0.06501349 0.013136341 0.05656268 -0.0415723...
# 8247  [0.005435122 -0.025132079 0.015010854 -0.03842...
# 8248  [-0.020894008 0.02490764 0.028566448 -0.082831...
#
# [8249 rows x 5 columns]

# %%
#Reset index for the DataFrame
df_10_percent_data = df_10_percent_data.reset_index(drop=True)
df_10_percent_data
# Out:
#            id                                      Movies/Series  \
# 0     9180533                         the.message.(1976).eng.1cd
# 1     9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2     9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3     9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4     9180600                              broker.(2022).eng.1cd
# ...       ...                                                ...
# 8244  9215813                      gossamer.folds.(2020).eng.1cd
# 8245  9215815                      gossamer.folds.(2020).eng.1cd
# 8246  9215856                 the.app.from.heaven.(2017).eng.1cd
# 8247  9215897    orient.s02.e07.a.matter.of.trust.(2022).eng.1cd
# 8248  9215903                spitfire.over.berlin.(2022).eng.1cd
#
#                                               subtitles  \
# 0     watch any video online with opensubtitles free...
# 1     ah theres princess dawn and terry with the blo...
# 2     iyumis cells i iepisode extremely polite yumii...
# 3     watch any video online with opensubtitles free...
# 4     watch any video online with opensubtitles free...
# ...                                                 ...
# 8244  apiopensubtitlesorg is deprecated please imple...
# 8245  advertise your product or brand here contact w...
# 8246  watch any video online with opensubtitles free...
# 8247  script info title english us original script k...
# 8248  support us and become vip member to remove all...
#
#                                          bert_embedding  \
# 0     [0.0429545, 0.047213517, -0.048022557, -0.0589...
# 1     [-0.017032498, 0.0084469365, 0.07423645, -0.01...
# 2     [-0.04869099, -0.04203135, 0.06548537, 0.03954...
# 3     [-0.043026306, -0.03555924, 0.059036024, -0.04...
# 4     [-0.024402311, 0.013387982, 0.123676725, -0.02...
# ...                                                 ...
# 8244  [0.077503555, -0.041504238, 0.03078112, -0.035...
# 8245  [0.033693567, -0.08421364, 0.07477469, -0.0781...
# 8246  [-0.06501349, 0.013136341, 0.05656268, -0.0415...
# 8247  [0.005435122, -0.025132079, 0.015010854, -0.03...
# 8248  [-0.020894008, 0.02490764, 0.028566448, -0.082...
#
#                                   bert_embedding_chunks
# 0     [0.0429545 0.047213517 -0.048022557 -0.0589091...
# 1     [-0.017032498 0.0084469365 0.07423645 -0.01032...
# 2     [-0.04869099 -0.04203135 0.06548537 0.03954125...
# 3     [-0.043026306 -0.03555924 0.059036024 -0.04153...
# 4     [-0.024402311 0.013387982 0.123676725 -0.02826...
# ...                                                 ...
# 8244  [0.077503555 -0.041504238 0.03078112 -0.035498...
# 8245  [0.033693567 -0.08421364 0.07477469 -0.0781623...
# 8246  [-0.06501349 0.013136341 0.05656268 -0.0415723...
# 8247  [0.005435122 -0.025132079 0.015010854 -0.03842...
# 8248  [-0.020894008 0.02490764 0.028566448 -0.082831...
#
# [8249 rows x 5 columns]

# %% [markdown]
# ## Preparing indexes

# %%
len(df_10_percent_data['bert_embedding_chunks'])
# Out:
# 8249

# %%
def indexer(item):
    index = []
    temp_df = df_10_percent_data[df_10_percent_data['id'] == item]
    if not temp_df.empty:
        temp_index = temp_df.index[0]
        print("Temp index:", temp_index)
        bert_chunks_length = len(df_10_percent_data["bert_embedding_chunks"])
        print("Shape of bert_embedding_chunks DataFrame:", df_10_percent_data["bert_embedding_chunks"].shape)
        if temp_index < bert_chunks_length:
            for j in range(len(df_10_percent_data["bert_embedding_chunks"].iloc[temp_index])):
                index.append(str(item) + "-" + str(j))
            return index
        else:
            print("Index out of bounds for item:", item)
    else:
        print("Item not found in DataFrame:", item)
    return []

df_10_percent_data['num_list'] = df_10_percent_data['id'].apply(indexer)
# Out:
# Temp index: 0
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 1
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 2
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 3
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 4
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 5
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 6
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 7
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 9
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 10
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 11
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 12
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 13
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 14
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 15
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 16
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 17
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 18
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 19
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 20
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 21
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 22
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 23
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 24
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 25
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 26
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 27
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 28
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 29
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 30
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 31
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 32
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 33
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 34
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 35
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 36
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 37
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 38
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 39
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 40
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 41
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 42
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 43
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 44
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 45
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 46
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 47
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 48
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 49
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 50
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 51
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 52
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 53
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 54
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 55
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 56
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 57
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 58
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 59
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 60
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 61
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 62
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 63
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 64
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 65
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 66
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 67
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 68
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 69
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 70
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 71
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 72
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 73
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 74
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 75
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 76
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 77
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 78
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 79
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 80
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 81
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 82
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 83
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 84
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 85
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 86
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 87
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 88
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 89
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 90
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 91
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 92
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 93
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 94
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 95
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 96
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 97
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 98
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 99
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 100
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 101
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 102
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 103
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 104
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 105
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 106
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 107
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 108
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 109
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 110
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 111
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 112
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 113
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 114
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 115
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 116
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 117
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 118
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 119
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 120
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 121
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 122
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 123
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 124
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 125
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 126
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 127
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 128
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 129
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 130
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 131
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 132
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 133
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 134
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 135
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 136
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 137
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 138
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 139
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 140
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 141
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 142
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 143
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 144
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 145
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 146
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 147
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 148
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 149
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 150
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 151
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 152
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 153
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 154
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 155
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 156
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 157
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 158
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 159
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 160
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 161
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 162
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 163
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 164
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 165
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 166
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 167
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 168
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 169
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 170
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 171
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 172
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 173
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 174
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 175
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 176
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 177
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 178
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 179
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 180
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 181
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 182
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 183
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 184
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 185
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 186
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 187
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 188
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 189
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 190
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 191
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 192
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 193
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 194
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 195
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 196
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 197
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 198
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 199
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 200
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 201
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 202
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 203
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 204
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 205
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 206
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 207
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 208
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 209
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 210
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 211
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 212
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 213
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 214
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 215
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 216
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 217
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 218
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 219
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 220
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 221
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 222
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 223
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 224
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 225
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 226
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 227
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 228
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 229
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 230
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 231
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 232
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 233
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 234
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 235
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 236
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 237
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 238
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 239
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 240
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 241
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 242
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 243
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 244
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 245
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 246
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 247
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 248
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 249
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 250
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 251
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 252
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 253
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 254
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 255
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 256
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 257
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 258
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 259
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 260
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 261
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 262
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 263
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 264
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 265
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 266
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 267
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 268
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 269
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 270
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 271
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 272
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 273
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 274
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 275
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 276
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 277
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 278
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 279
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 280
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 281
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 282
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 283
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 284
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 285
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 286
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 287
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 288
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 289
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 290
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 291
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 292
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 293
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 294
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 295
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 296
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 297
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 298
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 299
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 300
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 301
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 302
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 303
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 304
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 305
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 306
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 307
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 308
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 309
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 310
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 311
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 312
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 313
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 314
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 315
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 316
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 317
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 318
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 319
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 320
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 321
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 322
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 323
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 324
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 325
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 326
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 327
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 328
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 329
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 330
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 331
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 332
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 333
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 334
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 335
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 336
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 337
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 338
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 339
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 340
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 341
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 342
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 343
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 344
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 345
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 346
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 347
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 348
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 349
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 350
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 351
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 352
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 353
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 354
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 355
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 356
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 357
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 358
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 359
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 360
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 361
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 362
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 363
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 364
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 365
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 366
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 367
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 368
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 369
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 370
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 371
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 372
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 373
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 374
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 375
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 376
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 377
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 378
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 379
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 380
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 381
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 382
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 383
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 384
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 385
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 386
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 387
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 388
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 389
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 390
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 391
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 392
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 393
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 394
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 395
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 396
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 397
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 398
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 399
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 400
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 401
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 402
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 403
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 404
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 405
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 406
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 407
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 408
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 409
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 410
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 411
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 412
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 413
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 414
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 415
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 416
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 417
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 418
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 419
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 420
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 421
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 422
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 423
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 424
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 425
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 426
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 427
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 428
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 429
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 430
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 431
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 432
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 433
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 434
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 435
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 436
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 437
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 438
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 439
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 440
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 441
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 442
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 443
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 444
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 445
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 446
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 447
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 448
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 449
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 450
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 451
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 452
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 453
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 454
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 455
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 456
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 457
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 458
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 459
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 460
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 461
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 462
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 463
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 464
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 465
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 466
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 467
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 468
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 469
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 470
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 471
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 472
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 473
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 474
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 475
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 476
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 477
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 478
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 479
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 480
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 481
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 482
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 483
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 484
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 485
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 486
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 487
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 488
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 489
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 490
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 491
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 492
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 493
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 494
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 495
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 496
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 497
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 498
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 499
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 500
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 501
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 502
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 503
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 504
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 505
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 506
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 507
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 508
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 509
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 510
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 511
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 512
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 513
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 514
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 515
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 516
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 517
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 518
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 519
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 520
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 521
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 522
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 523
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 524
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 525
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 526
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 527
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 528
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 529
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 530
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 531
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 532
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 533
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 534
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 535
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 536
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 537
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 538
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 539
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 540
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 541
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 542
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 543
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 544
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 545
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 546
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 547
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 548
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 549
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 550
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 551
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 552
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 553
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 554
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 555
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 556
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 557
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 558
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 559
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 560
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 561
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 562
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 563
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 564
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 565
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 566
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 567
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 568
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 569
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 570
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 571
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 572
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 573
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 574
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 575
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 576
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 577
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 578
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 579
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 580
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 581
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 582
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 583
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 584
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 585
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 586
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 587
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 588
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 589
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 590
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 591
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 592
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 593
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 594
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 595
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 596
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 597
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 598
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 599
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 600
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 601
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 602
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 603
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 604
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 605
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 606
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 607
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 608
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 609
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 610
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 611
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 612
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 613
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 614
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 615
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 616
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 617
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 618
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 619
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 620
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 621
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 622
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 623
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 624
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 625
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 626
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 627
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 628
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 629
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 630
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 631
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 632
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 633
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 634
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 635
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 636
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 637
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 638
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 639
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 640
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 641
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 642
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 643
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 644
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 645
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 646
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 647
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 648
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 649
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 650
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 651
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 652
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 653
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 654
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 655
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 656
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 657
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 658
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 659
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 660
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 661
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 662
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 663
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 664
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 665
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 666
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 667
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 668
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 669
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 670
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 671
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 672
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 673
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 674
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 675
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 676
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 677
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 678
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 679
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 680
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 681
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 682
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 683
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 684
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 685
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 686
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 687
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 688
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 689
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 690
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 691
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 692
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 693
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 694
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 695
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 696
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 697
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 698
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 699
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 700
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 701
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 702
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 703
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 704
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 705
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 706
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 707
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 708
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 709
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 710
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 711
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 712
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 713
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 714
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 715
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 716
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 717
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 718
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 719
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 720
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 721
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 722
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 723
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 724
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 725
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 726
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 727
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 728
# ...
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8011
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8012
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8013
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8014
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8015
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8016
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8017
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8018
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8019
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8020
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8021
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8022
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8023
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8024
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8025
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8026
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8027
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8028
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8029
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8030
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8031
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8032
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8033
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8034
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8035
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8036
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8037
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8038
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8039
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8040
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8041
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8042
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8043
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8044
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8045
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8046
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8047
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8048
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8049
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8050
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8051
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8052
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8053
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8054
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8055
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8056
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8057
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8058
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8059
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8060
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8061
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8062
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8063
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8064
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8065
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8066
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8067
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8068
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8069
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8070
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8071
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8072
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8073
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8074
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8075
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8076
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8077
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8078
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8079
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8080
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8081
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8082
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8083
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8084
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8085
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8086
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8087
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8088
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8089
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8090
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8091
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8092
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8093
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8094
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8095
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8096
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8097
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8098
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8099
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8100
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8101
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8102
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8103
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8104
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8105
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8106
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8107
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8108
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8109
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8110
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8111
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8112
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8113
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8114
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8115
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8116
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8117
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8118
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8119
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8120
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8121
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8122
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8123
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8124
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8125
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8126
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8127
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8128
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8129
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8130
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8131
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8132
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8133
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8134
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8135
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8136
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8137
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8138
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8139
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8140
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8141
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8142
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8143
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8144
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8145
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8146
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8147
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8148
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8149
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8150
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8151
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8152
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8153
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8154
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8155
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8156
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8157
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8158
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8159
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8160
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8161
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8162
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8163
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8164
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8165
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8166
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8167
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8168
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8169
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8170
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8171
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8172
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8173
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8174
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8175
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8176
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8177
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8178
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8179
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8180
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8181
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8182
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8183
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8184
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8185
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8186
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8187
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8188
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8189
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8190
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8191
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8192
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8193
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8194
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8195
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8196
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8197
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8198
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8199
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8200
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8201
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8202
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8203
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8204
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8205
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8206
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8207
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8208
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8209
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8210
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8211
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8212
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8213
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8214
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8215
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8216
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8217
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8218
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8219
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8220
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8221
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8222
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8223
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8224
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8225
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8226
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8227
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8228
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8229
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8230
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8231
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8232
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8233
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8234
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8235
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8236
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8237
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8238
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8239
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8240
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8241
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8242
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8243
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8244
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8245
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8246
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8247
# Shape of bert_embedding_chunks DataFrame: (8249,)
# Temp index: 8248
# Shape of bert_embedding_chunks DataFrame: (8249,)

# %% [markdown]
# ## Stroringng embeddings in a ChromaDB database.

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\deshp\anaconda3\lib\site-packages (0.4.24)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\deshp\\anaconda3\\Lib\\site-packages\\~7mpy\\.libs\\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (3.10.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (4.1.0)
# Collecting numpy>=1.22.5
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Requirement already satisfied: importlib-resources in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (4.66.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (0.110.2)
# Requirement already satisfied: pydantic>=1.9 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (2.7.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: requests>=2.28 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (0.29.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (1.17.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (1.62.2)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (6.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\deshp\anaconda3\lib\site-packages (from chromadb) (4.10.0)
# Requirement already satisfied: pyproject_hooks in c:\users\deshp\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\deshp\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: colorama in c:\users\deshp\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.4)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\deshp\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.2)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\deshp\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (7.0.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\deshp\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\deshp\anaconda3\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.7.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2021.10.8)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: requests-oauthlib in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.9)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\deshp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\deshp\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\deshp\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\deshp\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: coloredlogs in c:\users\deshp\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: sympy in c:\users\deshp\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Requirement already satisfied: flatbuffers in c:\users\deshp\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\deshp\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\deshp\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.12.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (61.2.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\deshp\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\deshp\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\deshp\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\deshp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\deshp\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\deshp\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deshp\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deshp\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (3.3)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\deshp\anaconda3\lib\site-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deshp\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in c:\users\deshp\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.21.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\deshp\anaconda3\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.3.0)
# Requirement already satisfied: filelock in c:\users\deshp\anaconda3\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.6.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\deshp\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\deshp\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\deshp\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deshp\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deshp\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deshp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: h11>=0.8 in c:\users\deshp\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\deshp\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\deshp\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\deshp\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\deshp\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\deshp\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\deshp\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\deshp\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4

# %%
pip install protobuf==3.20.0
# Out:
# Collecting protobuf==3.20.0
#   Using cached protobuf-3.20.0-cp39-cp39-win_amd64.whl (904 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\deshp\\anaconda3\\Lib\\site-packages\\google\\~-pb\\_message.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)

# %%
pip install --user protobuf==3.20.0
# Out:
# Requirement already satisfied: protobuf==3.20.0 in c:\users\deshp\anaconda3\lib\site-packages (3.20.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\deshp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\deshp\anaconda3\lib\site-packages)

# %%
import chromadb
import os

# %%
client = chromadb.PersistentClient(path="C:/Users/deshp/Downloads/data/chromadb_saved_file/chroma.sqlite3")

# %%
collection = client.get_or_create_collection(
        name="subtitles",
        metadata={"hnsw:space": "cosine"} # l2 is the default
    )

# %%
def add_func():
    
    for i in range(df.shape[0]): #setting the range as total no. of rows in dataframe
        collection.add(
       
        embeddings=df_10_percent_data['bert_embedding'].iloc[i], # adding the corresponding chunk embedding
        documents=df_10_percent_data['bert_embedding_chunks'].iloc[i],  # adding each chunk
        subtit = df_10_percent_data['subtitles'].iloc[i],
        movies= df_10_percentage_data['Movies/Series'],
        ids=df_10_percent_data['num_list'].iloc[i] #entering the unique 'num' id
        )

# %%
results=collection.query(query_texts=["This is a query document"],n_results=10)

# %%
df.to_csv('df_10_percentage.csv', index=False, escapechar='\\')

# Providing a download link
from IPython.display import FileLink
FileLink('df_10_percentage.csv')
# Out:
# C:\Users\deshp\Downloads\df_10_percentage.csv
